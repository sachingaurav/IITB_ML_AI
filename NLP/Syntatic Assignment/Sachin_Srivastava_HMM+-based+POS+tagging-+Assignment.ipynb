# %% [markdown]
# # Problem Statement
# #We learnt to build our own HMM-based POS tagger and implement the Viterbi algorithm using the Penn Treebank training
# #corpus. The vanilla Viterbi algorithm we had written had resulted in ~87% accuracy. The approx. 13% loss of accuracy
# #was majorly due to the fact that when the algorithm encountered an unknown word(i.e. not present in the training set, such as #'Twitter'), it assigned an incorrect tag arbitrarily.#This is because, for unknown words, the emission probabilities for all candidate tags are 0, so the algorithm arbitrarily#chooses (the first) tag.In this assignment, we need to modify the Viterbi algorithm to solve the problem of unknown words using at least two techniques. Though there could be multiple ways to solve this problem,following hints can be considered:
# #Find tag class that most unknown words belong to.Then identify rules (e.g. based on morphological cues) that can be used to tag unknown words?
# #Viterbi algorithm chooses a random tag on encountering an unknown word.

# %% [markdown]
# # Approach adopted for the solution
#
# #1.Import the libraries and the data(pre read)
# #2.Understand the data.Perform EDA
# #3.Split the data into train(95%) and test(5%) sets
# #4.Peform vanilla Viterbi Hueristics and capture accuracy and unknown words
# #5.Modify Viterbi function to perform Unigram and Combination taggers with backoff fucntionality
# #6. Capture accuracy improvements with new changes
# #7.Check performance of test file against vanilla Viterbi and Combination taggers to capture tagging improvements

# %% [markdown]
# ## Data Preparation

# %%
#Importing required libraries
import nltk
import nltk, re, pprint
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import pprint, time
import random
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize

# %%
#reading the Treebank tagged sentences
nltk_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %%
# looking at the first 10 tagged sentences
print(nltk_data[:10])
# Out:
# [[('Pierre', 'NOUN'), ('Vinken', 'NOUN'), (',', '.'), ('61', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), (',', '.'), ('will', 'VERB'), ('join', 'VERB'), ('the', 'DET'), ('board', 'NOUN'), ('as', 'ADP'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('Nov.', 'NOUN'), ('29', 'NUM'), ('.', '.')], [('Mr.', 'NOUN'), ('Vinken', 'NOUN'), ('is', 'VERB'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Elsevier', 'NOUN'), ('N.V.', 'NOUN'), (',', '.'), ('the', 'DET'), ('Dutch', 'NOUN'), ('publishing', 'VERB'), ('group', 'NOUN'), ('.', '.')], [('Rudolph', 'NOUN'), ('Agnew', 'NOUN'), (',', '.'), ('55', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), ('and', 'CONJ'), ('former', 'ADJ'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Consolidated', 'NOUN'), ('Gold', 'NOUN'), ('Fields', 'NOUN'), ('PLC', 'NOUN'), (',', '.'), ('was', 'VERB'), ('named', 'VERB'), ('*-1', 'X'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('of', 'ADP'), ('this', 'DET'), ('British', 'ADJ'), ('industrial', 'ADJ'), ('conglomerate', 'NOUN'), ('.', '.')], [('A', 'DET'), ('form', 'NOUN'), ('of', 'ADP'), ('asbestos', 'NOUN'), ('once', 'ADV'), ('used', 'VERB'), ('*', 'X'), ('*', 'X'), ('to', 'PRT'), ('make', 'VERB'), ('Kent', 'NOUN'), ('cigarette', 'NOUN'), ('filters', 'NOUN'), ('has', 'VERB'), ('caused', 'VERB'), ('a', 'DET'), ('high', 'ADJ'), ('percentage', 'NOUN'), ('of', 'ADP'), ('cancer', 'NOUN'), ('deaths', 'NOUN'), ('among', 'ADP'), ('a', 'DET'), ('group', 'NOUN'), ('of', 'ADP'), ('workers', 'NOUN'), ('exposed', 'VERB'), ('*', 'X'), ('to', 'PRT'), ('it', 'PRON'), ('more', 'ADV'), ('than', 'ADP'), ('30', 'NUM'), ('years', 'NOUN'), ('ago', 'ADP'), (',', '.'), ('researchers', 'NOUN'), ('reported', 'VERB'), ('0', 'X'), ('*T*-1', 'X'), ('.', '.')], [('The', 'DET'), ('asbestos', 'NOUN'), ('fiber', 'NOUN'), (',', '.'), ('crocidolite', 'NOUN'), (',', '.'), ('is', 'VERB'), ('unusually', 'ADV'), ('resilient', 'ADJ'), ('once', 'ADP'), ('it', 'PRON'), ('enters', 'VERB'), ('the', 'DET'), ('lungs', 'NOUN'), (',', '.'), ('with', 'ADP'), ('even', 'ADV'), ('brief', 'ADJ'), ('exposures', 'NOUN'), ('to', 'PRT'), ('it', 'PRON'), ('causing', 'VERB'), ('symptoms', 'NOUN'), ('that', 'DET'), ('*T*-1', 'X'), ('show', 'VERB'), ('up', 'PRT'), ('decades', 'NOUN'), ('later', 'ADJ'), (',', '.'), ('researchers', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('*T*-2', 'X'), ('.', '.')], [('Lorillard', 'NOUN'), ('Inc.', 'NOUN'), (',', '.'), ('the', 'DET'), ('unit', 'NOUN'), ('of', 'ADP'), ('New', 'ADJ'), ('York-based', 'ADJ'), ('Loews', 'NOUN'), ('Corp.', 'NOUN'), ('that', 'DET'), ('*T*-2', 'X'), ('makes', 'VERB'), ('Kent', 'NOUN'), ('cigarettes', 'NOUN'), (',', '.'), ('stopped', 'VERB'), ('using', 'VERB'), ('crocidolite', 'NOUN'), ('in', 'ADP'), ('its', 'PRON'), ('Micronite', 'NOUN'), ('cigarette', 'NOUN'), ('filters', 'NOUN'), ('in', 'ADP'), ('1956', 'NUM'), ('.', '.')], [('Although', 'ADP'), ('preliminary', 'ADJ'), ('findings', 'NOUN'), ('were', 'VERB'), ('reported', 'VERB'), ('*-2', 'X'), ('more', 'ADV'), ('than', 'ADP'), ('a', 'DET'), ('year', 'NOUN'), ('ago', 'ADP'), (',', '.'), ('the', 'DET'), ('latest', 'ADJ'), ('results', 'NOUN'), ('appear', 'VERB'), ('in', 'ADP'), ('today', 'NOUN'), ("'s", 'PRT'), ('New', 'NOUN'), ('England', 'NOUN'), ('Journal', 'NOUN'), ('of', 'ADP'), ('Medicine', 'NOUN'), (',', '.'), ('a', 'DET'), ('forum', 'NOUN'), ('likely', 'ADJ'), ('*', 'X'), ('to', 'PRT'), ('bring', 'VERB'), ('new', 'ADJ'), ('attention', 'NOUN'), ('to', 'PRT'), ('the', 'DET'), ('problem', 'NOUN'), ('.', '.')], [('A', 'DET'), ('Lorillard', 'NOUN'), ('spokewoman', 'NOUN'), ('said', 'VERB'), (',', '.'), ('``', '.'), ('This', 'DET'), ('is', 'VERB'), ('an', 'DET'), ('old', 'ADJ'), ('story', 'NOUN'), ('.', '.')], [('We', 'PRON'), ("'re", 'VERB'), ('talking', 'VERB'), ('about', 'ADP'), ('years', 'NOUN'), ('ago', 'ADP'), ('before', 'ADP'), ('anyone', 'NOUN'), ('heard', 'VERB'), ('of', 'ADP'), ('asbestos', 'NOUN'), ('having', 'VERB'), ('any', 'DET'), ('questionable', 'ADJ'), ('properties', 'NOUN'), ('.', ...

# %%
# Converting the list of sentences to a list of (word, pos tag) tuples
tagged_words = [tup for sent in nltk_data for tup in sent]
print(len(tagged_words))
tagged_words[:10]
# Out:
# 100676
# [('Pierre', 'NOUN'),
#  ('Vinken', 'NOUN'),
#  (',', '.'),
#  ('61', 'NUM'),
#  ('years', 'NOUN'),
#  ('old', 'ADJ'),
#  (',', '.'),
#  ('will', 'VERB'),
#  ('join', 'VERB'),
#  ('the', 'DET')]

# %%
# Use the set() function to list the of all tags.We then find the the number of unique POS tags in the corpus
tags = [pair[1] for pair in tagged_words]
unique_tags = set(tags)
len(unique_tags)
# Out:
# 12

# %%
# Finding the most frequent tag in the corpus using the Counter() class from collections module
from collections import Counter
tag_counts = Counter(tags)
tag_counts
# Out:
# Counter({'NOUN': 28867,
#          '.': 11715,
#          'NUM': 3546,
#          'ADJ': 6397,
#          'VERB': 13564,
#          'DET': 8725,
#          'ADP': 9857,
#          'CONJ': 2265,
#          'X': 6613,
#          'ADV': 3171,
#          'PRT': 3219,
#          'PRON': 2737})

# %%
# Listing the 5 most common tags using the most_common() method of Counter
tag_counts.most_common(5)
# Out:
# [('NOUN', 28867), ('VERB', 13564), ('.', 11715), ('ADP', 9857), ('DET', 8725)]

# %% [markdown]
# # Splitting the datase into train and test sets

# %%
#Splitting the corpus into train and test,checking the lenght of each set 
random.seed(1234)
train_set, test_set = train_test_split(nltk_data,test_size=0.05)

print(len(train_set))
print(len(test_set))
# Out:
# 3718
# 196

# %%
#Printing the sentences in train set
print(test_set[:10])
# Out:
# [[('Volatility', 'NOUN'), ('surrounding', 'VERB'), ('his', 'PRON'), ('trades', 'NOUN'), ('occurs', 'VERB'), ('not', 'ADV'), ('because', 'ADP'), ('of', 'ADP'), ('index', 'NOUN'), ('arbitrage', 'NOUN'), (',', '.'), ('but', 'CONJ'), ('because', 'ADP'), ('his', 'PRON'), ('is', 'VERB'), ('a', 'DET'), ('large', 'ADJ'), ('addition', 'NOUN'), ('or', 'CONJ'), ('subtraction', 'NOUN'), ('to', 'PRT'), ('a', 'DET'), ('widget', 'NOUN'), ('market', 'NOUN'), ('with', 'ADP'), ('finite', 'ADJ'), ('liquidity', 'NOUN'), ('.', '.')], [('The', 'DET'), ('British', 'NOUN'), ('Department', 'NOUN'), ('of', 'ADP'), ('Trade', 'NOUN'), ('and', 'CONJ'), ('Industry', 'NOUN'), ('ordered', 'VERB'), ('an', 'DET'), ('investigation', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('competitive', 'ADJ'), ('impact', 'NOUN'), ('of', 'ADP'), ('Michelin', 'NOUN'), ('Tyre', 'NOUN'), ('PLC', 'NOUN'), ("'s", 'PRT'), ('planned', 'VERB'), ('acquisition', 'NOUN'), ('of', 'ADP'), ('National', 'NOUN'), ('Tyre', 'NOUN'), ('Service', 'NOUN'), ('Ltd', 'NOUN'), ('.', '.')], [('Guarantee', 'NOUN'), ('by', 'ADP'), ('Dai-Ichi', 'NOUN'), ('Kangyo', 'NOUN'), ('Bank', 'NOUN'), ('Ltd', 'NOUN'), ('.', '.')], [('Sea', 'NOUN'), ('Containers', 'NOUN'), ('Ltd.', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('it', 'PRON'), ('might', 'VERB'), ('increase', 'VERB'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('its', 'PRON'), ('$', '.'), ('70-a-share', 'ADJ'), ('*U*', 'X'), ('buy-back', 'ADJ'), ('plan', 'NOUN'), ('if', 'ADP'), ('*-2', 'X'), ('pressed', 'VERB'), ('*-1', 'X'), ('by', 'ADP'), ('Temple', 'NOUN'), ('Holdings', 'NOUN'), ('Ltd.', 'NOUN'), (',', '.'), ('which', 'DET'), ('*T*-156', 'X'), ('made', 'VERB'), ('an', 'DET'), ('earlier', 'ADJ'), ('tender', 'ADJ'), ('offer', 'NOUN'), ('for', 'ADP'), ('Sea', 'NOUN'), ('Containers', 'NOUN'), ('.', '.')], [('But', 'CONJ'), ('``', '.'), ('the', 'DET'), ('concept', 'NOUN'), ('is', 'VERB'), ('workable', 'ADJ'), ('.', '.')], [('When', 'ADV'), ('Scoring', 'NOUN'), ('High', 'NOUN'), ('first', 'ADV'), ('came', 'VERB'), ('out', 'ADV'), ('in', 'ADP'), ('1979', 'NUM'), ('*T*-1', 'X'), (',', '.'), ('it', 'PRON'), ('was', 'VERB'), ('a', 'DET'), ('publication', 'NOUN'), ('of', 'ADP'), ('Random', 'NOUN'), ('House', 'NOUN'), ('.', '.')], [('The', 'DET'), ('benchmark', 'NOUN'), ('was', 'VERB'), ('priced', 'VERB'), ('*-1', 'X'), ('at', 'ADP'), ('102', 'NUM'), ('22\\/32', 'NUM'), ('*-2', 'X'), ('to', 'PRT'), ('yield', 'VERB'), ('7.88', 'NUM'), ('%', 'NOUN'), ('compared', 'VERB'), ('with', 'ADP'), ('102', 'NUM'), ('12\\/32', 'NUM'), ('*', 'X'), ('to', 'PRT'), ('yield', 'VERB'), ('7.90', 'NUM'), ('%', 'NOUN'), ('Tuesday', 'NOUN'), ('.', '.')], [('--', '.'), ('Pat', 'NOUN'), ("D'Amico", 'NOUN'), ('.', '.')], [('The', 'DET'), ('Herald', 'NOUN'), ('joins', 'VERB'), ('the', 'DET'), ('Baltimore', 'NOUN'), ('News-American', 'NOUN'), (',', '.'), ('which', 'DET'), ('*T*-46', 'X'), ('folded', 'VERB'), (',', '.'), ('and', 'CONJ'), ('the', 'DET'), ('Boston', 'NOUN'), ('Herald-American', 'NOUN'), (',', '.'), ('which', 'DET'), ('*T*-1', 'X'), ('was', 'VERB'), ('sold', 'VERB'), ('*-62', 'X'), (',', '.'), ('as', 'ADP'), ('cornerstones', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('old', 'ADJ'), ('Hearst', 'NOUN'), ('newspaper', 'NOUN'), ('empire', 'NOUN'), ('abandoned', 'VERB'), ('*', 'X'), ('by', 'ADP'), ('the', 'DET'), ('company', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('1980s', 'NUM'), ('.', '.')], [('Lentjes', 'NOUN'), ("'", 'PRT'), ('product', 'NOUN'), ('mix', 'NOUN'), ('of', 'ADP'), ('specialized', 'VERB'), ('boilers', 'NOUN'), ('and', 'CONJ'), ('pipes', 'NOUN'), ('provides', 'VERB'), ('a', 'DET'), ('good', 'ADJ'), ('fit', 'NOUN'), ('with', 'ADP'), ('its', 'PRON'), ('own', 'ADJ'), ('Lurgi', 'NOUN'), ('G.m.b', 'NOUN'), ('.', '.'), ('H.', 'NOUN'), ('plant', 'NOUN'), ('engineering', 'VERB'), ('unit', 'NOUN'), (',', '.'), ('the', 'DET'), ('company', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('*T*-1', 'X'), ('.', '.')]]

# %%
# Get the list of tagged words from train set
train_tagged_words = [tup for sent in train_set for tup in sent]
len(train_tagged_words)
# Out:
# 95999

# %%
# Print the list of tagged words from train set.
train_tagged_words
# Out:
# [('Middlesex', 'NOUN'),
#  ('Water', 'NOUN'),
#  ('Co.', 'NOUN'),
#  (',', '.'),
#  ('offering', 'VERB'),
#  ('of', 'ADP'),
#  ('150,000', 'NUM'),
#  ('shares', 'NOUN'),
#  ('of', 'ADP'),
#  ('common', 'ADJ'),
#  ('stock', 'NOUN'),
#  (',', '.'),
#  ('via', 'ADP'),
#  ('Legg', 'NOUN'),
#  ('Mason', 'NOUN'),
#  ('Wood', 'NOUN'),
#  ('Walker', 'NOUN'),
#  ('Inc.', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Howard', 'NOUN'),
#  (',', '.'),
#  ('Weil', 'NOUN'),
#  (',', '.'),
#  ('Labouisse', 'NOUN'),
#  (',', '.'),
#  ('Friedrichs', 'NOUN'),
#  ('Inc', 'NOUN'),
#  ('.', '.'),
#  ('AMR', 'NOUN'),
#  ('climbed', 'VERB'),
#  ('1', 'NUM'),
#  ('3\\/4', 'NUM'),
#  ('to', 'PRT'),
#  ('73', 'NUM'),
#  ('1\\/8', 'NUM'),
#  ('amid', 'ADP'),
#  ('rumors', 'NOUN'),
#  ('that', 'ADP'),
#  ('New', 'NOUN'),
#  ('York', 'NOUN'),
#  ('developer', 'NOUN'),
#  ('Donald', 'NOUN'),
#  ('Trump', 'NOUN'),
#  ('was', 'VERB'),
#  ('seeking', 'VERB'),
#  ('financing', 'NOUN'),
#  ('0', 'X'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('mount', 'VERB'),
#  ('a', 'DET'),
#  ('new', 'ADJ'),
#  (',', '.'),
#  ('lower', 'ADJ'),
#  ('offer', 'NOUN'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('parent', 'NOUN'),
#  ('company', 'NOUN'),
#  ('of', 'ADP'),
#  ('American', 'NOUN'),
#  ('Airlines', 'NOUN'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('city', 'NOUN'),
#  ("'s", 'PRT'),
#  ('Campaign', 'NOUN'),
#  ('Finance', 'NOUN'),
#  ('Board', 'NOUN'),
#  ('has', 'VERB'),
#  ('refused', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('pay', 'VERB'),
#  ('Mr.', 'NOUN'),
#  ('Dinkins', 'NOUN'),
#  ('$', '.'),
#  ('95,142', 'NUM'),
#  ('*U*', 'X'),
#  ('in', 'ADP'),
#  ('matching', 'ADJ'),
#  ('funds', 'NOUN'),
#  ('because', 'ADP'),
#  ('his', 'PRON'),
#  ('campaign', 'NOUN'),
#  ('records', 'NOUN'),
#  ('are', 'VERB'),
#  ('incomplete', 'ADJ'),
#  ('.', '.'),
#  ('He', 'PRON'),
#  ('says', 'VERB'),
#  ('0', 'X'),
#  ('Campbell', 'NOUN'),
#  ('was', 'VERB'),
#  ("n't", 'ADV'),
#  ('even', 'ADV'),
#  ('contacted', 'VERB'),
#  ('*-1', 'X'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('magazine', 'NOUN'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('opportunity', 'NOUN'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('comment', 'VERB'),
#  ('.', '.'),
#  ('Dealers', 'NOUN'),
#  ('led', 'VERB'),
#  ('the', 'DET'),
#  ('market', 'NOUN'),
#  ('Wednesday', 'NOUN'),
#  ('by', 'ADP'),
#  ('*-1', 'X'),
#  ('actively', 'ADV'),
#  ('trading', 'VERB'),
#  ('for', 'ADP'),
#  ('their', 'PRON'),
#  ('own', 'ADJ'),
#  ('accounts', 'NOUN'),
#  (',', '.'),
#  ('observers', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('*T*-2', 'X'),
#  ('.', '.'),
#  ('It', 'PRON'),
#  ("'s", 'VERB'),
#  ('fueled', 'VERB'),
#  ('*-1', 'X'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('increasing', 'VERB'),
#  ('profitability', 'NOUN'),
#  ('of', 'ADP'),
#  ('major-league', 'ADJ'),
#  ('teams', 'NOUN'),
#  ('.', '.'),
#  ('As', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('digs', 'VERB'),
#  ('out', 'PRT'),
#  ('from', 'ADP'),
#  ('The', 'DET'),
#  ('Pretty', 'NOUN'),
#  ('Big', 'NOUN'),
#  ('One', 'NUM'),
#  (',', '.'),
#  ('opponents', 'NOUN'),
#  ('say', 'VERB'),
#  ('0', 'X'),
#  ('the', 'DET'),
#  ('last', 'ADJ'),
#  ('thing', 'NOUN'),
#  ('0', 'X'),
#  ('the', 'DET'),
#  ('city', 'NOUN'),
#  ('can', 'VERB'),
#  ('afford', 'VERB'),
#  ('*T*-1', 'X'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('expensive', 'ADJ'),
#  ('new', 'ADJ'),
#  ('stadium', 'NOUN'),
#  ('.', '.'),
#  ('Yasser', 'NOUN'),
#  ('Arafat', 'NOUN'),
#  ('has', 'VERB'),
#  ('written', 'VERB'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('chairman', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('International', 'NOUN'),
#  ('Olympic', 'NOUN'),
#  ('Committee', 'NOUN'),
#  ('*-2', 'X'),
#  ('asking', 'VERB'),
#  ('him', 'PRON'),
#  ('*-3', 'X'),
#  ('to', 'PRT'),
#  ('back', 'VERB'),
#  ('a', 'DET'),
#  ('Palestinian', 'ADJ'),
#  ('bid', 'NOUN'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('join', 'VERB'),
#  ('the', 'DET'),
#  ('committee', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('Palestine', 'NOUN'),
#  ('Liberation', 'NOUN'),
#  ('Organization', 'NOUN'),
#  ('news', 'NOUN'),
#  ('agency', 'NOUN'),
#  ('WAFA', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('they', 'PRON'),
#  ('have', 'VERB'),
#  ("n't", 'ADV'),
#  ('clarified', 'VERB'),
#  ('what', 'PRON'),
#  ('those', 'DET'),
#  ('might', 'VERB'),
#  ('be', 'VERB'),
#  ('*T*-187', 'X'),
#  ('.', '.'),
#  ('Nearby', 'ADJ'),
#  ('cities', 'NOUN'),
#  ('such', 'ADJ'),
#  ('as', 'ADP'),
#  ('Pasadena', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Long', 'NOUN'),
#  ('Beach', 'NOUN'),
#  ('also', 'ADV'),
#  ('have', 'VERB'),
#  ('large', 'ADJ'),
#  ('dailies', 'NOUN'),
#  ('.', '.'),
#  ('Mr.', 'NOUN'),
#  ('Coleman', 'NOUN'),
#  ('said', 'VERB'),
#  ('this', 'DET'),
#  ('week', 'NOUN'),
#  ('that', 'ADP'),
#  ('he', 'PRON'),
#  ('would', 'VERB'),
#  ('devote', 'VERB'),
#  ('the', 'DET'),
#  ('remainder', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('political', 'ADJ'),
#  ('season', 'NOUN'),
#  ('to', 'PRT'),
#  ('positive', 'ADJ'),
#  ('campaigning', 'NOUN'),
#  (',', '.'),
#  ('but', 'CONJ'),
#  ('the', 'DET'),
#  ('truce', 'NOUN'),
#  ('lasted', 'VERB'),
#  ('only', 'ADV'),
#  ('hours', 'NOUN'),
#  ('.', '.'),
#  ('They', 'PRON'),
#  ('have', 'VERB'),
#  ('begun', 'VERB'),
#  ('*-1', 'X'),
#  ('sending', 'VERB'),
#  ('letters', 'NOUN'),
#  ('explaining', 'VERB'),
#  ('the', 'DET'),
#  ('program', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-52', 'X'),
#  ('began', 'VERB'),
#  ('Oct.', 'NOUN'),
#  ('18', 'NUM'),
#  ('and', 'CONJ'),
#  ('will', 'VERB'),
#  ('end', 'VERB'),
#  ('Dec.', 'NOUN'),
#  ('18', 'NUM'),
#  (',', '.'),
#  ('to', 'PRT'),
#  ('about', 'ADP'),
#  ('five', 'NUM'),
#  ('million', 'NUM'),
#  ('card', 'NOUN'),
#  ('holders', 'NOUN'),
#  ('.', '.'),
#  ('His', 'PRON'),
#  ('wife', 'NOUN'),
#  ('also', 'ADV'),
#  ('works', 'VERB'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('paper', 'NOUN'),
#  (',', '.'),
#  ('as', 'ADP'),
#  ('did', 'VERB'),
#  ('his', 'PRON'),
#  ('father', 'NOUN'),
#  ('.', '.'),
#  ('Lentjes', 'NOUN'),
#  ('had', 'VERB'),
#  ('1988', 'NUM'),
#  ('sales', 'NOUN'),
#  ('of', 'ADP'),
#  ('800', 'NUM'),
#  ('million', 'NUM'),
#  ('marks', 'NOUN'),
#  ('-LRB-', '.'),
#  ('$', '.'),
#  ('434.4', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('-RRB-', '.'),
#  ('and', 'CONJ'),
#  ('has', 'VERB'),
#  ('a', 'DET'),
#  ('current', 'ADJ'),
#  ('order', 'NOUN'),
#  ('backlog', 'NOUN'),
#  ('of', 'ADP'),
#  ('2.5', 'NUM'),
#  ('billion', 'NUM'),
#  ('marks', 'NOUN'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('others', 'NOUN'),
#  ('at', 'ADP'),
#  ('Greenville', 'NOUN'),
#  ('High', 'NOUN'),
#  ('say', 'VERB'),
#  ('0', 'X'),
#  ('she', 'PRON'),
#  ('was', 'VERB'),
#  ('eager', 'ADJ'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('win', 'VERB'),
#  ('--', '.'),
#  ('if', 'ADJ'),
#  ('not', 'ADV'),
#  ('for', 'ADP'),
#  ('money', 'NOUN'),
#  (',', '.'),
#  ('then', 'ADV'),
#  ('for', 'ADP'),
#  ('pride', 'NOUN'),
#  ('and', 'CONJ'),
#  ('recognition', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('bill', 'NOUN'),
#  (',', '.'),
#  ('as', 'ADP'),
#  ('it', 'PRON'),
#  ('was', 'VERB'),
#  ('approved', 'VERB'),
#  ('*-26', 'X'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('House', 'NOUN'),
#  ('Public', 'NOUN'),
#  ('Works', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Transportation', 'NOUN'),
#  ('Committee', 'NOUN'),
#  (',', '.'),
#  ('would', 'VERB'),
#  ('give', 'VERB'),
#  ('the', 'DET'),
#  ('Transportation', 'NOUN'),
#  ('Department', 'NOUN'),
#  ('up', 'ADP'),
#  ('to', 'PRT'),
#  ('50', 'NUM'),
#  ('days', 'NOUN'),
#  ('0', 'X'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('review', 'VERB'),
#  ('any', 'DET'),
#  ('purchase', 'NOUN'),
#  ('of', 'ADP'),
#  ('15', 'NUM'),
#  ('%', 'NOUN'),
#  ('or', 'CONJ'),
#  ('more', 'ADJ'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('stock', 'NOUN'),
#  ('in', 'ADP'),
#  ('an', 'DET'),
#  ('airline', 'NOUN'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('A', 'DET'),
#  ('medium-sized', 'ADJ'),
#  ('one', 'NUM'),
#  ('in', 'ADP'),
#  ('Brooklyn', 'NOUN'),
#  (',', '.'),
#  ('it', 'PRON'),
#  ('says', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  (',', '.'),
#  ('could', 'VERB'),
#  ('be', 'VERB'),
#  ('altered', 'VERB'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('house', 'VERB'),
#  ('up', 'ADP'),
#  ('to', 'PRT'),
#  ('1,000', 'NUM'),
#  ('inmates', 'NOUN'),
#  ('at', 'ADP'),
#  ('a', 'DET'),
#  ('lower', 'ADJ'),
#  ('cost', 'NOUN'),
#  ('than', 'ADP'),
#  ('*', 'X'),
#  ('building', 'VERB'),
#  ('a', 'DET'),
#  ('new', 'ADJ'),
#  ('prison', 'NOUN'),
#  ('in', 'ADP'),
#  ('upstate', 'ADJ'),
#  ('New', 'NOUN'),
#  ('York', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('The', 'DET'),
#  ('sharp', 'ADJ'),
#  ('stock', 'NOUN'),
#  ('market', 'NOUN'),
#  ('decline', 'NOUN'),
#  ('in', 'ADP'),
#  ('late', 'ADJ'),
#  ('October', 'NOUN'),
#  ('appears', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('have', 'VERB'),
#  ('had', 'VERB'),
#  ('little', 'ADJ'),
#  ('or', 'CONJ'),
#  ('no', 'DET'),
#  ('effect', 'NOUN'),
#  ('on', 'ADP'),
#  ('consumers', 'NOUN'),
#  (',', '.'),
#  ("''", '.'),
#  ('said', 'VERB'),
#  ('*T*-2', 'X'),
#  ('Fabian', 'NOUN'),
#  ('Linden', 'NOUN'),
#  (',', '.'),
#  ('executive', 'ADJ'),
#  ('director', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('Conference', 'NOUN'),
#  ('Board', 'NOUN'),
#  ("'s", 'PRT'),
#  ('consumer', 'NOUN'),
#  ('research', 'NOUN'),
#  ('center', 'NOUN'),
#  ('.', '.'),
#  ('Preliminary', 'ADJ'),
#  ('tallies', 'NOUN'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('Trade', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Industry', 'NOUN'),
#  ('Ministry', 'NOUN'),
#  ('showed', 'VERB'),
#  ('another', 'DET'),
#  ('trade', 'NOUN'),
#  ('deficit', 'NOUN'),
#  ('in', 'ADP'),
#  ('October', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('fifth', 'ADJ'),
#  ('monthly', 'ADJ'),
#  ('setback', 'NOUN'),
#  ('this', 'DET'),
#  ('year', 'NOUN'),
#  (',', '.'),
#  ('*', 'X'),
#  ('casting', 'VERB'),
#  ('a', 'DET'),
#  ('cloud', 'NOUN'),
#  ('on', 'ADP'),
#  ('South', 'NOUN'),
#  ('Korea', 'NOUN'),
#  ("'s", 'PRT'),
#  ('export-oriented', 'ADJ'),
#  ('economy', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('We', 'PRON'),
#  ('thought', 'VERB'),
#  ('0', 'X'),
#  ('it', 'PRON'),
#  ('was', 'VERB'),
#  ('awfully', 'ADV'),
#  ('expensive', 'ADJ'),
#  (',', '.'),
#  ("''", '.'),
#  ('said', 'VERB'),
#  ('*T*-2', 'X'),
#  ('Sterling', 'NOUN'),
#  ('Pratt', 'NOUN'),
#  (',', '.'),
#  ('wine', 'NOUN'),
#  ('director', 'NOUN'),
#  ('at', 'ADP'),
#  ('Schaefer', 'NOUN'),
#  ("'s", 'PRT'),
#  ('in', 'ADP'),
#  ('Skokie', 'NOUN'),
#  (',', '.'),
#  ('Ill.', 'NOUN'),
#  (',', '.'),
#  ('one', 'NUM'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('top', 'ADJ'),
#  ('stores', 'NOUN'),
#  ('in', 'ADP'),
#  ('suburban', 'ADJ'),
#  ('Chicago', 'NOUN'),
#  (',', '.'),
#  ('``', '.'),
#  ('but', 'CONJ'),
#  ('there', 'DET'),
#  ('are', 'VERB'),
#  ('people', 'NOUN'),
#  ('out', 'ADP'),
#  ('there', 'ADV'),
#  ('with', 'ADP'),
#  ('very', 'ADV'),
#  ('different', 'ADJ'),
#  ('opinions', 'NOUN'),
#  ('of', 'ADP'),
#  ('value', 'NOUN'),
#  ('.', '.'),
#  ('All', 'DET'),
#  ('four', 'NUM'),
#  ('areas', 'NOUN'),
#  ('had', 'VERB'),
#  ('higher', 'ADJ'),
#  ('revenue', 'NOUN'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('three', 'NUM'),
#  ('months', 'NOUN'),
#  ('ended', 'VERB'),
#  ('Sept.', 'NOUN'),
#  ('30', 'NUM'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Ideas', 'NOUN'),
#  ('are', 'VERB'),
#  ('going', 'VERB'),
#  ('over', 'ADP'),
#  ('borders', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('there', 'DET'),
#  ("'s", 'VERB'),
#  ('no', 'DET'),
#  ('SDI', 'NOUN'),
#  ('ideological', 'ADJ'),
#  ('weapon', 'NOUN'),
#  ('that', 'DET'),
#  ('*T*-245', 'X'),
#  ('can', 'VERB'),
#  ('shoot', 'VERB'),
#  ('them', 'PRON'),
#  ('down', 'ADP'),
#  (',', '.'),
#  ("''", '.'),
#  ('he', 'PRON'),
#  ('told', 'VERB'),
#  ('a', 'DET'),
#  ('group', 'NOUN'),
#  ('of', 'ADP'),
#  ('Americans', 'NOUN'),
#  ('*T*-1', 'X'),
#  ('at', 'ADP'),
#  ('the', 'DET'),
#  ('U.S.', 'NOUN'),
#  ('Embassy', 'NOUN'),
#  ('on', 'ADP'),
#  ('Wednesday', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('program', 'NOUN'),
#  ('traders', 'NOUN'),
#  (',', '.'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('other', 'ADJ'),
#  ('hand', 'NOUN'),
#  (',', '.'),
#  ('portray', 'VERB'),
#  ('old-fashioned', 'ADJ'),
#  ('stock', 'NOUN'),
#  ('pickers', 'NOUN'),
#  ('as', 'ADP'),
#  ('the', 'DET'),
#  ('Neanderthals', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('industry', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('company', 'NOUN'),
#  ('recently', 'ADV'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('it', 'PRON'),
#  ('would', 'VERB'),
#  ('sell', 'VERB'),
#  ('some', 'DET'),
#  ('operations', 'NOUN'),
#  ('and', 'CONJ'),
#  ('lay', 'VERB'),
#  ('off', 'PRT'),
#  ('4', 'NUM'),
#  ('%', 'NOUN'),
#  ('of', 'ADP'),
#  ('its', 'PRON'),
#  ('work', 'NOUN'),
#  ('force', 'NOUN'),
#  (',', '.'),
#  ('altogether', 'ADV'),
#  ('*-1', 'X'),
#  ('reducing', 'VERB'),
#  ('employment', 'NOUN'),
#  ('to', 'PRT'),
#  ('less', 'ADV'),
#  ('than', 'ADP'),
#  ('16,000', 'NUM'),
#  ('from', 'ADP'),
#  ('about', 'ADP'),
#  ('18,000', 'NUM'),
#  ('.', '.'),
#  ('``', '.'),
#  ('The', 'DET'),
#  ('economy', 'NOUN'),
#  ('is', 'VERB'),
#  ('clearly', 'ADV'),
#  ('slowing', 'VERB'),
#  (',', '.'),
#  ("''", '.'),
#  ('says', 'VERB'),
#  ('*T*-1', 'X'),
#  ('Robert', 'NOUN'),
#  ('Black', 'NOUN'),
#  (',', '.'),
#  ('president', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('Richmond', 'NOUN'),
#  ('Federal', 'NOUN'),
#  ('Reserve', 'NOUN'),
#  ('Bank', 'NOUN'),
#  ('.', '.'),
#  ('Stock', 'NOUN'),
#  ('prices', 'NOUN'),
#  ('rose', 'VERB'),
#  ('fractionally', 'ADV'),
#  ('in', 'ADP'),
#  ('moderate', 'ADJ'),
#  ('trading', 'VERB'),
#  ('.', '.'),
#  ('Test-preparation', 'ADJ'),
#  ('booklets', 'NOUN'),
#  (',', '.'),
#  ('software', 'NOUN'),
#  ('and', 'CONJ'),
#  ('worksheets', 'NOUN'),
#  ('are', 'VERB'),
#  ('a', 'DET'),
#  ('booming', 'VERB'),
#  ('publishing', 'VERB'),
#  ('subindustry', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('She', 'PRON'),
#  ('did', 'VERB'),
#  ('a', 'DET'),
#  ('lot', 'NOUN'),
#  ('of', 'ADP'),
#  ('harm', 'NOUN'),
#  (',', '.'),
#  ("''", '.'),
#  ('says', 'VERB'),
#  ('*T*-1', 'X'),
#  ('Cathryn', 'NOUN'),
#  ('Rice', 'NOUN'),
#  (',', '.'),
#  ('who', 'PRON'),
#  ('*T*-100', 'X'),
#  ('had', 'VERB'),
#  ('discovered', 'VERB'),
#  ('the', 'DET'),
#  ('crib', 'NOUN'),
#  ('notes', 'NOUN'),
#  ('.', '.'),
#  ('Image', 'NOUN'),
#  ('has', 'VERB'),
#  (',', '.'),
#  ('of', 'ADP'),
#  ('course', 'NOUN'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('great', 'ADJ'),
#  ('deal', 'NOUN'),
#  ('0', 'X'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('do', 'VERB'),
#  ('*T*-1', 'X'),
#  ('with', 'ADP'),
#  ('what', 'PRON'),
#  ('*T*-170', 'X'),
#  ('sells', 'VERB'),
#  ('and', 'CONJ'),
#  ('what', 'PRON'),
#  ('*T*-171', 'X'),
#  ('does', 'VERB'),
#  ("n't", 'ADV'),
#  ('*?*', 'X'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('it', 'PRON'),
#  ('ca', 'VERB'),
#  ("n't", 'ADV'),
#  ('be', 'VERB'),
#  ('forced', 'VERB'),
#  ('*-100', 'X'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('*', 'X'),
#  ('maintaining', 'VERB'),
#  ('U.S.', 'NOUN'),
#  ('influence', 'NOUN'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('difficult', 'ADJ'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('face', 'NOUN'),
#  ('of', 'ADP'),
#  ('Japanese', 'ADJ'),
#  ('dominance', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('region', 'NOUN'),
#  ('.', '.'),
#  ('Some', 'DET'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('surge', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('stock', 'NOUN'),
#  ("'s", 'PRT'),
#  ('price', 'NOUN'),
#  ('appeared', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('linked', 'VERB'),
#  ('*-39', 'X'),
#  ('to', 'PRT'),
#  ('revived', 'VERB'),
#  ('takeover', 'NOUN'),
#  ('speculation', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-28', 'X'),
#  ('has', 'VERB'),
#  ('contributed', 'VERB'),
#  ('to', 'PRT'),
#  ('volatility', 'NOUN'),
#  ('of', 'ADP'),
#  ('Campbell', 'NOUN'),
#  ('shares', 'NOUN'),
#  ('in', 'ADP'),
#  ('recent', 'ADJ'),
#  ('months', 'NOUN'),
#  ('.', '.'),
#  ('Futures', 'NOUN'),
#  ('traders', 'NOUN'),
#  ('respond', 'VERB'),
#  ('that', 'ADP'),
#  ('low', 'ADJ'),
#  ('margins', 'NOUN'),
#  ('help', 'VERB'),
#  ('*-1', 'X'),
#  ('keep', 'VERB'),
#  ('their', 'PRON'),
#  ('markets', 'NOUN'),
#  ('active', 'ADJ'),
#  ('.', '.'),
#  ('Analysts', 'NOUN'),
#  ('were', 'VERB'),
#  ('disappointed', 'VERB'),
#  ('*-112', 'X'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('enthusiasm', 'NOUN'),
#  ('*ICH*-2', 'X'),
#  ('0', 'X'),
#  ('investors', 'NOUN'),
#  ('showed', 'VERB'),
#  ('*T*-1', 'X'),
#  ('for', 'ADP'),
#  ('stocks', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('wake', 'NOUN'),
#  ('of', 'ADP'),
#  ('Georgia-Pacific', 'NOUN'),
#  ("'s", 'PRT'),
#  ('$', '.'),
#  ('3.18', 'NUM'),
#  ('billion', 'NUM'),
#  ('*U*', 'X'),
#  ('bid', 'NOUN'),
#  ('for', 'ADP'),
#  ('Great', 'ADJ'),
#  ('Northern', 'NOUN'),
#  ('Nekoosa', 'NOUN'),
#  ('evaporated', 'VERB'),
#  ('so', 'ADV'),
#  ('quickly', 'ADV'),
#  ('.', '.'),
#  ('Mr.', 'NOUN'),
#  ('Bush', 'NOUN'),
#  ('has', 'VERB'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('he', 'PRON'),
#  ('would', 'VERB'),
#  ('like', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('able', 'ADJ'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('use', 'VERB'),
#  ('this', 'DET'),
#  ('procedure', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('addition', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('Apple', 'NOUN'),
#  ('II', 'NOUN'),
#  ('was', 'VERB'),
#  ('an', 'DET'),
#  ('affordable', 'ADJ'),
#  ('$', '.'),
#  ('1,298', 'NUM'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('If', 'ADP'),
#  ('Boeing', 'NOUN'),
#  ('goes', 'VERB'),
#  ('ahead', 'ADV'),
#  ('with', 'ADP'),
#  ('the', 'DET'),
#  ('larger', 'ADJ'),
#  ('767', 'NUM'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('plane', 'NOUN'),
#  ('could', 'VERB'),
#  ('hit', 'VERB'),
#  ('the', 'DET'),
#  ('market', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('mid-1990s', 'NOUN'),
#  ('.', '.'),
#  ('By', 'ADP'),
#  ('comparison', 'NOUN'),
#  (',', '.'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('nine', 'NUM'),
#  ('months', 'NOUN'),
#  (',', '.'),
#  ('Xerox', 'NOUN'),
#  ('earned', 'VERB'),
#  ('$', '.'),
#  ('492', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  (',', '.'),
#  ('or', 'CONJ'),
#  ('$', '.'),
#  ('4.55', 'NUM'),
#  ('*U*', 'X'),
#  ('a', 'DET'),
#  ('share', 'NOUN'),
#  (',', '.'),
#  ('on', 'ADP'),
#  ('revenue', 'NOUN'),
#  ('of', 'ADP'),
#  ('$', '.'),
#  ('12.97', 'NUM'),
#  ('billion', 'NUM'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('After', 'ADP'),
#  ('your', 'PRON'),
#  ('first', 'ADJ'),
#  ('three', 'NUM'),
#  ('weeks', 'NOUN'),
#  ('of', 'ADP'),
#  ('sleep', 'NOUN'),
#  ('deprivation', 'NOUN'),
#  (',', '.'),
#  ('you', 'PRON'),
#  ("'re", 'VERB'),
#  ('scarcely', 'ADV'),
#  ('in', 'ADP'),
#  ('touch', 'NOUN'),
#  ('with', 'ADP'),
#  ('reality', 'NOUN'),
#  ('any', 'DET'),
#  ('more', 'ADV'),
#  (';', '.'),
#  ('without', 'ADP'),
#  ('psychiatric', 'ADJ'),
#  ('treatment', 'NOUN'),
#  (',', '.'),
#  ('you', 'PRON'),
#  ('may', 'VERB'),
#  ('well', 'ADV'),
#  ('be', 'VERB'),
#  ('unable', 'ADJ'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('fend', 'VERB'),
#  ('for', 'ADP'),
#  ('yourself', 'PRON'),
#  ('ever', 'ADV'),
#  ('again', 'ADV'),
#  ('.', '.'),
#  ("''", '.'),
#  ('``', '.'),
#  ('If', 'ADP'),
#  ('I', 'PRON'),
#  ('took', 'VERB'),
#  ('-LCB-', '.'),
#  ('these', 'DET'),
#  ('preparation', 'NOUN'),
#  ('booklets', 'NOUN'),
#  ('-RCB-', '.'),
#  ('into', 'ADP'),
#  ('my', 'PRON'),
#  ('classroom', 'NOUN'),
#  (',', '.'),
#  ('I', 'PRON'),
#  ("'d", 'VERB'),
#  ('have', 'VERB'),
#  ('a', 'DET'),
#  ('hard', 'ADJ'),
#  ('time', 'NOUN'),
#  ('*-1', 'X'),
#  ('justifying', 'VERB'),
#  ('to', 'PRT'),
#  ('my', 'PRON'),
#  ('students', 'NOUN'),
#  ('and', 'CONJ'),
#  ('parents', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('was', 'VERB'),
#  ("n't", 'ADV'),
#  ('cheating', 'NOUN'),
#  (',', '.'),
#  ("''", '.'),
#  ('says', 'VERB'),
#  ('*T*-2', 'X'),
#  ('John', 'NOUN'),
#  ('Kaminski', 'NOUN'),
#  (',', '.'),
#  ('a', 'DET'),
#  ...]

# %%
# Getting tokens for tagged words from train set 
tokens = [pair[0] for pair in train_tagged_words]
tokens[:10]
# Out:
# ['Middlesex',
#  'Water',
#  'Co.',
#  ',',
#  'offering',
#  'of',
#  '150,000',
#  'shares',
#  'of',
#  'common']

# %%
# printing the length ofvocabulary
V = set(tokens)
print(len(V))
# Out:
# 12068

# %%
# Printing the count of number of tags
T = set([pair[1] for pair in train_tagged_words])
len(T)
# Out:
# 12

# %%
# printing the 12 tags that are their in the train set
print(T)
# Out:
# {'PRON', 'NUM', 'X', 'DET', 'CONJ', 'ADP', 'ADV', 'VERB', '.', 'NOUN', 'PRT', 'ADJ'}

# %% [markdown]
# # Build the vanilla Viterbi based POS tagger

# %%
# computing P(w/t) and storing in T x V matrix
t = len(T)
v = len(V)
w_given_t = np.zeros((t, v))

# %% [markdown]
# ### Emission Probability

# %%
# compute word given tag: Emission Probability
def word_given_tag(word, tag, train_bag = train_tagged_words):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    count_w_given_tag = len(w_given_tag_list)
    
    return (count_w_given_tag, count_tag)

# %%
# Test the above function with few examples
# forthcoming
print("\n", "forthcoming")
print(word_given_tag('forthcoming', 'ADJ'))
print(word_given_tag('forthcoming', 'VERB'))
print(word_given_tag('forthcoming', 'NOUN'), "\n")
# in
print("\n", "in")
print(word_given_tag('in', 'ADP'))
print(word_given_tag('in', 'ADJ'))
print(word_given_tag('in', 'VERB'))
# Satellite
print("\n", "Satellite")
print(word_given_tag('book', 'NOUN'))
print(word_given_tag('book', 'VERB'))
# Out:
#  forthcoming
# (1, 6127)
# (0, 12956)
# (0, 27480)
#
#
#  in
# (1494, 9427)
# (0, 6127)
# (0, 12956)
#
#  Satellite
# (7, 27480)
# (1, 12956)

# %% [markdown]
# ### Transition Probability

# %%
# compute tag given tag: tag2(t2) given tag1 (t1), i.e. Transition Probability

def t2_given_t1(t2, t1, train_bag = train_tagged_words):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
# Test the above function with few examples
print(t2_given_t1(t2='NOUN', t1='ADJ'))
print(t2_given_t1('NOUN', 'DET'))
print(t2_given_t1('NOUN', 'VERB'))
print(t2_given_t1('.', 'NOUN'))
# Out:
# (4285, 6127)
# (5312, 8332)
# (1419, 12956)
# (6587, 27480)

# %%
# creating t x t transition matrix of tags
# each column is t2, each row is t1
# thus M(i, j) represents P(tj given ti)

tags_matrix = np.zeros((len(T), len(T)), dtype='float32')
for i, t1 in enumerate(list(T)):
    for j, t2 in enumerate(list(T)): 
        count_t2_t1, count_t1 = t2_given_t1(t2, t1)
        tags_matrix[i, j] = count_t2_t1/count_t1

# %%
# matrix in a df for better readability
tags_df = pd.DataFrame(tags_matrix, columns = list(T), index=list(T))
tags_df
# Out:
#           PRON       NUM         X       DET      CONJ       ADP       ADV  \
# PRON  0.007695  0.007311  0.093882  0.010004  0.005387  0.021932  0.034244
# NUM   0.001784  0.184007  0.209572  0.003270  0.013377  0.035969  0.002973
# X     0.055134  0.002844  0.075671  0.054028  0.010427  0.146130  0.026224
# DET   0.003721  0.021964  0.045247  0.005641  0.000480  0.009241  0.012602
# CONJ  0.059232  0.041647  0.008792  0.121240  0.000463  0.054604  0.055530
# ADP   0.068845  0.062692  0.034369  0.324175  0.000743  0.016866  0.013578
# ADV   0.014812  0.032258  0.023700  0.068137  0.006912  0.116853  0.078670
# VERB  0.034964  0.022769  0.218972  0.133374  0.005403  0.091386  0.082356
# .     0.065432  0.080892  0.027234  0.174636  0.058691  0.091587  0.052490
# NOUN  0.004767  0.009243  0.029258  0.013355  0.042722  0.177220  0.017140
# PRT   0.017980  0.054920  0.013730  0.101994  0.001961  0.020595  0.010461
# ADJ   0.000653  0.021054  0.020238  0.005060  0.016321  0.078179  0.004407
#
#           VERB         .      NOUN       PRT       ADJ
# PRON  0.482493  0.040015  0.208927  0.012697  0.075414
# NUM   0.018728  0.118312  0.351665  0.026754  0.033591
# X     0.203949  0.161453  0.062243  0.184676  0.017220
# DET   0.040326  0.017283  0.637542  0.000240  0.205713
# CONJ  0.156409  0.033781  0.346599  0.005090  0.116613
# ADP   0.007638  0.039673  0.322372  0.001485  0.107563
# ADV   0.343976  0.138249  0.030612  0.014812  0.131007
# VERB  0.170191  0.034656  0.109525  0.031723  0.064680
# .     0.089520  0.092666  0.220834  0.002337  0.043592
# NOUN  0.147234  0.239702  0.263974  0.043122  0.012263
# PRT   0.403727  0.042171  0.245505  0.001961  0.084995
# ADJ   0.012241  0.064469  0.699363  0.010935  0.067080

# %%
tags_df.loc['NOUN', :]
# Out:
# PRON    0.004767
# NUM     0.009243
# X       0.029258
# DET     0.013355
# CONJ    0.042722
# ADP     0.177220
# ADV     0.017140
# VERB    0.147234
# .       0.239702
# NOUN    0.263974
# PRT     0.043122
# ADJ     0.012263
# Name: NOUN, dtype: float32

# %% [markdown]
# # Viterbi Algorithm

# %%
len(train_tagged_words)
# Out:
# 95999

# %%
# Viterbi Heuristic
def Viterbi(words,sentence,train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            count_w_given_tag, count_tag = word_given_tag(words[key], tag)
            emission_p = count_w_given_tag/count_tag
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
#Evaluating on Test Set

random.seed(1234)

# choose random 5 sents
##rndom = [random.randint(1,196) for x in range(5)]
rndom = list(range(0,196))
# list of sents
test_run = [test_set[i] for i in rndom]
##test_run = [test_set]

# list of tagged words
test_run_base = [tup for sent in test_run for tup in sent]

# list of untagged words
test_tagged_words = [tup[0] for sent in test_run for tup in sent]
test_tagged_words
# Out:
# ['Volatility',
#  'surrounding',
#  'his',
#  'trades',
#  'occurs',
#  'not',
#  'because',
#  'of',
#  'index',
#  'arbitrage',
#  ',',
#  'but',
#  'because',
#  'his',
#  'is',
#  'a',
#  'large',
#  'addition',
#  'or',
#  'subtraction',
#  'to',
#  'a',
#  'widget',
#  'market',
#  'with',
#  'finite',
#  'liquidity',
#  '.',
#  'The',
#  'British',
#  'Department',
#  'of',
#  'Trade',
#  'and',
#  'Industry',
#  'ordered',
#  'an',
#  'investigation',
#  'of',
#  'the',
#  'competitive',
#  'impact',
#  'of',
#  'Michelin',
#  'Tyre',
#  'PLC',
#  "'s",
#  'planned',
#  'acquisition',
#  'of',
#  'National',
#  'Tyre',
#  'Service',
#  'Ltd',
#  '.',
#  'Guarantee',
#  'by',
#  'Dai-Ichi',
#  'Kangyo',
#  'Bank',
#  'Ltd',
#  '.',
#  'Sea',
#  'Containers',
#  'Ltd.',
#  'said',
#  '0',
#  'it',
#  'might',
#  'increase',
#  'the',
#  'price',
#  'of',
#  'its',
#  '$',
#  '70-a-share',
#  '*U*',
#  'buy-back',
#  'plan',
#  'if',
#  '*-2',
#  'pressed',
#  '*-1',
#  'by',
#  'Temple',
#  'Holdings',
#  'Ltd.',
#  ',',
#  'which',
#  '*T*-156',
#  'made',
#  'an',
#  'earlier',
#  'tender',
#  'offer',
#  'for',
#  'Sea',
#  'Containers',
#  '.',
#  'But',
#  '``',
#  'the',
#  'concept',
#  'is',
#  'workable',
#  '.',
#  'When',
#  'Scoring',
#  'High',
#  'first',
#  'came',
#  'out',
#  'in',
#  '1979',
#  '*T*-1',
#  ',',
#  'it',
#  'was',
#  'a',
#  'publication',
#  'of',
#  'Random',
#  'House',
#  '.',
#  'The',
#  'benchmark',
#  'was',
#  'priced',
#  '*-1',
#  'at',
#  '102',
#  '22\\/32',
#  '*-2',
#  'to',
#  'yield',
#  '7.88',
#  '%',
#  'compared',
#  'with',
#  '102',
#  '12\\/32',
#  '*',
#  'to',
#  'yield',
#  '7.90',
#  '%',
#  'Tuesday',
#  '.',
#  '--',
#  'Pat',
#  "D'Amico",
#  '.',
#  'The',
#  'Herald',
#  'joins',
#  'the',
#  'Baltimore',
#  'News-American',
#  ',',
#  'which',
#  '*T*-46',
#  'folded',
#  ',',
#  'and',
#  'the',
#  'Boston',
#  'Herald-American',
#  ',',
#  'which',
#  '*T*-1',
#  'was',
#  'sold',
#  '*-62',
#  ',',
#  'as',
#  'cornerstones',
#  'of',
#  'the',
#  'old',
#  'Hearst',
#  'newspaper',
#  'empire',
#  'abandoned',
#  '*',
#  'by',
#  'the',
#  'company',
#  'in',
#  'the',
#  '1980s',
#  '.',
#  'Lentjes',
#  "'",
#  'product',
#  'mix',
#  'of',
#  'specialized',
#  'boilers',
#  'and',
#  'pipes',
#  'provides',
#  'a',
#  'good',
#  'fit',
#  'with',
#  'its',
#  'own',
#  'Lurgi',
#  'G.m.b',
#  '.',
#  'H.',
#  'plant',
#  'engineering',
#  'unit',
#  ',',
#  'the',
#  'company',
#  'said',
#  '0',
#  '*T*-1',
#  '.',
#  'Upjohn',
#  'further',
#  'estimated',
#  'that',
#  'about',
#  '50',
#  '%',
#  'of',
#  'the',
#  'employees',
#  'who',
#  '*T*-2',
#  'leave',
#  'for',
#  'early',
#  'retirement',
#  'may',
#  'be',
#  'replaced',
#  '*-1',
#  '.',
#  'William',
#  'R.',
#  'Breakey',
#  'M.D.',
#  'Pamela',
#  'J.',
#  'Fischer',
#  'M.D.',
#  'Department',
#  'of',
#  'Psychiatry',
#  'Johns',
#  'Hopkins',
#  'University',
#  'School',
#  'of',
#  'Medicine',
#  'Baltimore',
#  'One',
#  'clear',
#  'sign',
#  'of',
#  'Japan',
#  "'s",
#  'nervousness',
#  'came',
#  'this',
#  'week',
#  ',',
#  'when',
#  'a',
#  'spokesman',
#  'for',
#  'Japan',
#  "'s",
#  'Foreign',
#  'Ministry',
#  'devoted',
#  'nearly',
#  'all',
#  'of',
#  'a',
#  'regular',
#  ',',
#  'half-hour',
#  'briefing',
#  'for',
#  'foreign',
#  'journalists',
#  'to',
#  'the',
#  'subject',
#  'of',
#  'recent',
#  'Japanese',
#  'investments',
#  'in',
#  'the',
#  'U.S.',
#  '*T*-1',
#  '.',
#  'Ratners',
#  'Group',
#  'PLC',
#  ',',
#  'a',
#  'fast-growing',
#  ',',
#  'acquisition-minded',
#  'London-based',
#  'jeweler',
#  ',',
#  'raised',
#  'its',
#  'price',
#  'for',
#  'Seattle-based',
#  'specialty',
#  'jeweler',
#  'Weisfield',
#  "'s",
#  'Inc.',
#  'to',
#  '$',
#  '57.50',
#  '*U*',
#  'a',
#  'share',
#  ',',
#  'or',
#  '$',
#  '62.1',
#  'million',
#  '*U*',
#  ',',
#  'from',
#  '$',
#  '50',
#  '*U*',
#  'a',
#  'share',
#  ',',
#  'or',
#  '$',
#  '55',
#  'million',
#  '*U*',
#  ',',
#  'after',
#  'another',
#  'concern',
#  'said',
#  '0',
#  'it',
#  'would',
#  'be',
#  'prepared',
#  '*-1',
#  'to',
#  'outbid',
#  'Ratners',
#  "'s",
#  'initial',
#  'offer',
#  '.',
#  'Sumitomo',
#  'Metal',
#  'Mining',
#  'fell',
#  'five',
#  'yen',
#  'to',
#  '692',
#  'and',
#  'Nippon',
#  'Mining',
#  'added',
#  '15',
#  'to',
#  '960',
#  '.',
#  'Japan',
#  "'s",
#  'reserves',
#  'of',
#  'gold',
#  ',',
#  'convertible',
#  'foreign',
#  'currencies',
#  ',',
#  'and',
#  'special',
#  'drawing',
#  'rights',
#  'fell',
#  'by',
#  'a',
#  'hefty',
#  '$',
#  '1.82',
#  'billion',
#  '*U*',
#  'in',
#  'October',
#  'to',
#  '$',
#  '84.29',
#  'billion',
#  '*U*',
#  ',',
#  'the',
#  'Finance',
#  'Ministry',
#  'said',
#  '0',
#  '*T*-2',
#  '.',
#  'And',
#  'construction',
#  'also',
#  'was',
#  'described',
#  '*-101',
#  'as',
#  'slow',
#  'in',
#  'most',
#  'areas',
#  '.',
#  'Carnival',
#  'said',
#  '0',
#  'the',
#  'Fantasy',
#  ',',
#  'a',
#  '2,050-passenger',
#  'ship',
#  'that',
#  '*T*-3',
#  'was',
#  'slated',
#  '*-4',
#  'to',
#  'be',
#  'delivered',
#  '*-2',
#  'this',
#  'month',
#  ',',
#  'will',
#  'be',
#  'delivered',
#  '*-1',
#  'in',
#  'January',
#  '.',
#  'John',
#  'Rowe',
#  ',',
#  'president',
#  '*RNR*-1',
#  'and',
#  'chief',
#  'executive',
#  'officer',
#  '*RNR*-1',
#  'of',
#  'New',
#  'England',
#  'Electric',
#  ',',
#  'said',
#  '0',
#  'the',
#  'company',
#  "'s",
#  'return',
#  'on',
#  'equity',
#  'could',
#  'suffer',
#  'if',
#  'it',
#  'made',
#  'a',
#  'higher',
#  'bid',
#  'and',
#  'its',
#  'forecasts',
#  'related',
#  '*',
#  'to',
#  'PS',
#  'of',
#  'New',
#  'Hampshire',
#  '--',
#  'such',
#  'as',
#  'growth',
#  'in',
#  'electricity',
#  'demand',
#  'and',
#  'improved',
#  'operating',
#  'efficiencies',
#  '--',
#  'did',
#  "n't",
#  'come',
#  'true',
#  '.',
#  'Only',
#  '19',
#  '%',
#  'of',
#  'the',
#  'purchasing',
#  'managers',
#  'reported',
#  'better',
#  'export',
#  'orders',
#  'in',
#  'October',
#  ',',
#  'down',
#  'from',
#  '27',
#  '%',
#  'in',
#  'September',
#  '.',
#  'Koito',
#  'has',
#  'refused',
#  '*-1',
#  'to',
#  'grant',
#  'Mr.',
#  'Pickens',
#  'seats',
#  'on',
#  'its',
#  'board',
#  ',',
#  '*-1',
#  'asserting',
#  '0',
#  'he',
#  'is',
#  'a',
#  'greenmailer',
#  'trying',
#  '*',
#  'to',
#  'pressure',
#  'Koito',
#  "'s",
#  'other',
#  'shareholders',
#  'into',
#  '*',
#  'buying',
#  'him',
#  'out',
#  'at',
#  'a',
#  'profit',
#  '.',
#  'The',
#  'American',
#  'Stock',
#  'Exchange',
#  'Market',
#  'Value',
#  'Index',
#  'gained',
#  '1.56',
#  'to',
#  '372.14',
#  '.',
#  'On',
#  'Wall',
#  'Street',
#  'men',
#  'and',
#  'women',
#  'walk',
#  'with',
#  'great',
#  'purpose',
#  ',',
#  '*-2',
#  'noticing',
#  'one',
#  'another',
#  'only',
#  'when',
#  'they',
#  'jostle',
#  'for',
#  'cabs',
#  '*T*-1',
#  '.',
#  'The',
#  'cases',
#  'quickly',
#  'went',
#  'to',
#  'court',
#  ',',
#  'but',
#  'the',
#  'mothers',
#  'of',
#  'several',
#  'thousand',
#  'DES',
#  'plaintiffs',
#  'could',
#  "n't",
#  'recall',
#  'whose',
#  'brand',
#  'they',
#  'used',
#  '*T*-1',
#  '.',
#  'He',
#  'said',
#  '0',
#  'more',
#  'than',
#  '90',
#  '%',
#  'of',
#  'the',
#  'funds',
#  'were',
#  'placed',
#  '*-40',
#  'with',
#  'Japanese',
#  'institutional',
#  'investors',
#  '.',
#  'It',
#  'did',
#  "n't",
#  'elaborate',
#  '.',
#  'Negotiable',
#  ',',
#  'bank-backed',
#  'business',
#  'credit',
#  'instruments',
#  'typically',
#  'financing',
#  'an',
#  'import',
#  'order',
#  '.',
#  'But',
#  'advancing',
#  'issues',
#  'on',
#  'the',
#  'New',
#  'York',
#  'Stock',
#  'Exchange',
#  'were',
#  'tidily',
#  'ahead',
#  'of',
#  'declining',
#  'stocks',
#  ',',
#  '847',
#  'to',
#  '644',
#  '.',
#  'The',
#  'department',
#  "'s",
#  'Occupational',
#  'Safety',
#  'and',
#  'Health',
#  'Administration',
#  'proposed',
#  'fines',
#  'of',
#  '$',
#  '6.1',
#  'million',
#  '*U*',
#  'for',
#  'alleged',
#  'violations',
#  'at',
#  'the',
#  'company',
#  "'s",
#  'Fairless',
#  'Hills',
#  ',',
#  'Pa.',
#  ',',
#  'steel',
#  'mill',
#  ';',
#  'that',
#  'was',
#  'a',
#  'record',
#  'for',
#  'proposed',
#  'penalties',
#  'at',
#  'any',
#  'single',
#  'facility',
#  '.',
#  'Imports',
#  'were',
#  'at',
#  '$',
#  '50.38',
#  'billion',
#  '*U*',
#  ',',
#  'up',
#  '19',
#  '%',
#  '.',
#  'Mr.',
#  'Sherwood',
#  'speculated',
#  'that',
#  'the',
#  'leeway',
#  'that',
#  'Sea',
#  'Containers',
#  'has',
#  '*T*-1',
#  'means',
#  'that',
#  'Temple',
#  'would',
#  'have',
#  '*-2',
#  'to',
#  '``',
#  'substantially',
#  'increase',
#  'their',
#  'bid',
#  'if',
#  'they',
#  "'re",
#  'going',
#  '*-3',
#  'to',
#  'top',
#  'us',
#  '.',
#  "''",
#  'Mr.',
#  'Giuliani',
#  "'s",
#  'campaign',
#  'chairman',
#  ',',
#  'Peter',
#  'Powers',
#  ',',
#  'says',
#  '0',
#  'the',
#  'Dinkins',
#  'ad',
#  'is',
#  '``',
#  'deceptive',
#  '.',
#  "''",
#  'If',
#  'not',
#  'Chicago',
#  ',',
#  'then',
#  'in',
#  'New',
#  'York',
#  ';',
#  'if',
#  'not',
#  'the',
#  'U.S.',
#  ',',
#  'then',
#  'overseas',
#  '.',
#  'But',
#  'the',
#  'prospects',
#  'for',
#  'legislation',
#  'that',
#  '*T*-1',
#  'targets',
#  'program',
#  'trading',
#  'is',
#  'unlikely',
#  'anytime',
#  'soon',
#  '.',
#  'As',
#  '*',
#  'discussed',
#  'in',
#  'the',
#  'context',
#  'of',
#  '*',
#  'controlling',
#  'federal',
#  'spending',
#  ',',
#  'the',
#  'line-item',
#  'veto',
#  'is',
#  'characterized',
#  '*-59',
#  'as',
#  'a',
#  'way',
#  '0',
#  'for',
#  'the',
#  'president',
#  'to',
#  'excise',
#  'perfectly',
#  'constitutional',
#  'provisions',
#  'in',
#  'a',
#  'spending',
#  'bill',
#  'that',
#  '*T*-2',
#  'are',
#  'objectionable',
#  'merely',
#  'because',
#  'they',
#  'conflict',
#  'with',
#  'his',
#  'policy',
#  'objectives',
#  '*T*-1',
#  '.',
#  'The',
#  'announcement',
#  'follows',
#  'a',
#  'sharper',
#  '$',
#  '2.2',
#  'billion',
#  '*U*',
#  'decline',
#  'in',
#  'the',
#  'country',
#  "'s",
#  'foreign',
#  'reserves',
#  'in',
#  'September',
#  'to',
#  '$',
#  '86.12',
#  'billion',
#  '*U*',
#  '.',
#  'A',
#  'free',
#  'market',
#  'with',
#  'a',
#  'profit',
#  'motive',
#  'will',
#  'attract',
#  'each',
#  'investor',
#  'to',
#  'the',
#  'liquidity',
#  'and',
#  'risks',
#  '0',
#  'he',
#  'can',
#  'tolerate',
#  '*T*-1',
#  '.',
#  'Many',
#  'Asians',
#  'regard',
#  'a',
#  'U.S.',
#  'presence',
#  'as',
#  'a',
#  'desirable',
#  'counterweight',
#  'to',
#  'Japanese',
#  'influence',
#  '.',
#  'The',
#  'Internal',
#  'Revenue',
#  'Service',
#  'has',
#  'threatened',
#  'criminal',
#  'sanctions',
#  'against',
#  'lawyers',
#  'who',
#  '*T*-123',
#  'fail',
#  '*-1',
#  'to',
#  'report',
#  'detailed',
#  'information',
#  'about',
#  'clients',
#  'who',
#  '*T*-124',
#  'pay',
#  'them',
#  'more',
#  'than',
#  '$',
#  '10,000',
#  '*U*',
#  'in',
#  'cash',
#  '.',
#  '``',
#  'We',
#  'do',
#  "n't",
#  'spend',
#  'much',
#  'on',
#  'print',
#  'advertising',
#  ',',
#  "''",
#  'she',
#  'says',
#  '*T*-1',
#  '.',
#  'Japan',
#  "'s",
#  'regulators',
#  'have',
#  'since',
#  'tightened',
#  'controls',
#  'on',
#  'index-related',
#  'stock',
#  'purchases',
#  '.',
#  'The',
#  'patent',
#  'covers',
#  'BMP-1',
#  'type',
#  ...]

# %% [markdown]
# ### Tagging the test sentence using vanilla Viterbi

# %%
# tagging the test sentences
start = time.time()
tagged_seq = Viterbi(test_tagged_words,train_set)
end = time.time()
difference = end-start

# %%
print("Time taken in seconds: ", difference)
print(tagged_seq)
#print(test_run_base)
# Out:
# Time taken in seconds:  279.4725477695465
# [('Volatility', 'NOUN'), ('surrounding', 'VERB'), ('his', 'PRON'), ('trades', 'NOUN'), ('occurs', 'VERB'), ('not', 'ADV'), ('because', 'ADP'), ('of', 'ADP'), ('index', 'NOUN'), ('arbitrage', 'NOUN'), (',', '.'), ('but', 'CONJ'), ('because', 'ADP'), ('his', 'PRON'), ('is', 'VERB'), ('a', 'DET'), ('large', 'ADJ'), ('addition', 'NOUN'), ('or', 'CONJ'), ('subtraction', 'PRON'), ('to', 'PRT'), ('a', 'DET'), ('widget', 'NOUN'), ('market', 'NOUN'), ('with', 'ADP'), ('finite', 'PRON'), ('liquidity', 'NOUN'), ('.', '.'), ('The', 'DET'), ('British', 'ADJ'), ('Department', 'NOUN'), ('of', 'ADP'), ('Trade', 'NOUN'), ('and', 'CONJ'), ('Industry', 'NOUN'), ('ordered', 'VERB'), ('an', 'DET'), ('investigation', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('competitive', 'ADJ'), ('impact', 'NOUN'), ('of', 'ADP'), ('Michelin', 'NOUN'), ('Tyre', 'NOUN'), ('PLC', 'NOUN'), ("'s", 'PRT'), ('planned', 'VERB'), ('acquisition', 'NOUN'), ('of', 'ADP'), ('National', 'NOUN'), ('Tyre', 'NOUN'), ('Service', 'NOUN'), ('Ltd', 'NOUN'), ('.', '.'), ('Guarantee', 'PRON'), ('by', 'ADP'), ('Dai-Ichi', 'NOUN'), ('Kangyo', 'NOUN'), ('Bank', 'NOUN'), ('Ltd', 'NOUN'), ('.', '.'), ('Sea', 'NOUN'), ('Containers', 'NOUN'), ('Ltd.', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('it', 'PRON'), ('might', 'VERB'), ('increase', 'VERB'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('its', 'PRON'), ('$', '.'), ('70-a-share', 'PRON'), ('*U*', 'X'), ('buy-back', 'NOUN'), ('plan', 'NOUN'), ('if', 'ADP'), ('*-2', 'X'), ('pressed', 'VERB'), ('*-1', 'X'), ('by', 'ADP'), ('Temple', 'NOUN'), ('Holdings', 'NOUN'), ('Ltd.', 'NOUN'), (',', '.'), ('which', 'DET'), ('*T*-156', 'PRON'), ('made', 'VERB'), ('an', 'DET'), ('earlier', 'ADJ'), ('tender', 'NOUN'), ('offer', 'NOUN'), ('for', 'ADP'), ('Sea', 'NOUN'), ('Containers', 'NOUN'), ('.', '.'), ('But', 'CONJ'), ('``', '.'), ('the', 'DET'), ('concept', 'NOUN'), ('is', 'VERB'), ('workable', 'PRON'), ('.', '.'), ('When', 'ADV'), ('Scoring', 'NOUN'), ('High', 'NOUN'), ('first', 'ADJ'), ('came', 'VERB'), ('out', 'PRT'), ('in', 'ADP'), ('1979', 'NUM'), ('*T*-1', 'X'), (',', '.'), ('it', 'PRON'), ('was', 'VERB'), ('a', 'DET'), ('publication', 'PRON'), ('of', 'ADP'), ('Random', 'NOUN'), ('House', 'NOUN'), ('.', '.'), ('The', 'DET'), ('benchmark', 'NOUN'), ('was', 'VERB'), ('priced', 'VERB'), ('*-1', 'X'), ('at', 'ADP'), ('102', 'PRON'), ('22\\/32', 'NUM'), ('*-2', 'X'), ('to', 'PRT'), ('yield', 'VERB'), ('7.88', 'NUM'), ('%', 'NOUN'), ('compared', 'VERB'), ('with', 'ADP'), ('102', 'PRON'), ('12\\/32', 'PRON'), ('*', 'X'), ('to', 'PRT'), ('yield', 'VERB'), ('7.90', 'NUM'), ('%', 'NOUN'), ('Tuesday', 'NOUN'), ('.', '.'), ('--', '.'), ('Pat', 'NOUN'), ("D'Amico", 'PRON'), ('.', '.'), ('The', 'DET'), ('Herald', 'NOUN'), ('joins', 'VERB'), ('the', 'DET'), ('Baltimore', 'NOUN'), ('News-American', 'PRON'), (',', '.'), ('which', 'DET'), ('*T*-46', 'X'), ('folded', 'PRON'), (',', '.'), ('and', 'CONJ'), ('the', 'DET'), ('Boston', 'NOUN'), ('Herald-American', 'PRON'), (',', '.'), ('which', 'DET'), ('*T*-1', 'X'), ('was', 'VERB'), ('sold', 'VERB'), ('*-62', 'X'), (',', '.'), ('as', 'ADP'), ('cornerstones', 'PRON'), ('of', 'ADP'), ('the', 'DET'), ('old', 'ADJ'), ('Hearst', 'NOUN'), ('newspaper', 'NOUN'), ('empire', 'NOUN'), ('abandoned', 'VERB'), ('*', 'X'), ('by', 'ADP'), ('the', 'DET'), ('company', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('1980s', 'NOUN'), ('.', '.'), ('Lentjes', 'NOUN'), ("'", 'PRT'), ('product', 'NOUN'), ('mix', 'NOUN'), ('of', 'ADP'), ('specialized', 'VERB'), ('boilers', 'PRON'), ('and', 'CONJ'), ('pipes', 'PRON'), ('provides', 'VERB'), ('a', 'DET'), ('good', 'ADJ'), ('fit', 'NOUN'), ('with', 'ADP'), ('its', 'PRON'), ('own', 'ADJ'), ('Lurgi', 'PRON'), ('G.m.b', 'PRON'), ('.', '.'), ('H.', 'NOUN'), ('plant', 'NOUN'), ('engineering', 'NOUN'), ('unit', 'NOUN'), (',', '.'), ('the', 'DET'), ('company', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('*T*-1', 'X'), ('.', '.'), ('Upjohn', 'NOUN'), ('further', 'ADV'), ('estimated', 'VERB'), ('that', 'ADP'), ( ...

# %% [markdown]
# ### Vanilla Viterbi Accuracy

# %%
# accuracy
check = [i for i, j in zip(tagged_seq, test_run_base) if i == j] 
accuracy = len(check)/len(tagged_seq)
print('The accuracy of vanilla vitrebi is :', accuracy)
# Out:
# The accuracy of vanilla vitrebi is : 0.8960872354073124

# %% [markdown]
# ### Incorrectly Tagged Words - Unknown Words

# %%
incorrect_tagged_cases = [[test_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq, test_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases
# Out:
# [[('or', 'CONJ'), (('subtraction', 'PRON'), ('subtraction', 'NOUN'))],
#  [('with', 'ADP'), (('finite', 'PRON'), ('finite', 'ADJ'))],
#  [('The', 'DET'), (('British', 'ADJ'), ('British', 'NOUN'))],
#  [('.', '.'), (('Guarantee', 'PRON'), ('Guarantee', 'NOUN'))],
#  [('$', '.'), (('70-a-share', 'PRON'), ('70-a-share', 'ADJ'))],
#  [('*U*', 'X'), (('buy-back', 'NOUN'), ('buy-back', 'ADJ'))],
#  [('which', 'DET'), (('*T*-156', 'PRON'), ('*T*-156', 'X'))],
#  [('earlier', 'ADJ'), (('tender', 'NOUN'), ('tender', 'ADJ'))],
#  [('is', 'VERB'), (('workable', 'PRON'), ('workable', 'ADJ'))],
#  [('High', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('came', 'VERB'), (('out', 'PRT'), ('out', 'ADV'))],
#  [('a', 'DET'), (('publication', 'PRON'), ('publication', 'NOUN'))],
#  [('at', 'ADP'), (('102', 'PRON'), ('102', 'NUM'))],
#  [('with', 'ADP'), (('102', 'PRON'), ('102', 'NUM'))],
#  [('102', 'NUM'), (('12\\/32', 'PRON'), ('12\\/32', 'NUM'))],
#  [('Pat', 'NOUN'), (("D'Amico", 'PRON'), ("D'Amico", 'NOUN'))],
#  [('Baltimore', 'NOUN'),
#   (('News-American', 'PRON'), ('News-American', 'NOUN'))],
#  [('*T*-46', 'X'), (('folded', 'PRON'), ('folded', 'VERB'))],
#  [('Boston', 'NOUN'),
#   (('Herald-American', 'PRON'), ('Herald-American', 'NOUN'))],
#  [('as', 'ADP'), (('cornerstones', 'PRON'), ('cornerstones', 'NOUN'))],
#  [('the', 'DET'), (('1980s', 'NOUN'), ('1980s', 'NUM'))],
#  [('specialized', 'VERB'), (('boilers', 'PRON'), ('boilers', 'NOUN'))],
#  [('and', 'CONJ'), (('pipes', 'PRON'), ('pipes', 'NOUN'))],
#  [('own', 'ADJ'), (('Lurgi', 'PRON'), ('Lurgi', 'NOUN'))],
#  [('Lurgi', 'NOUN'), (('G.m.b', 'PRON'), ('G.m.b', 'NOUN'))],
#  [('plant', 'NOUN'), (('engineering', 'NOUN'), ('engineering', 'VERB'))],
#  [('R.', 'NOUN'), (('Breakey', 'PRON'), ('Breakey', 'NOUN'))],
#  [('J.', 'NOUN'), (('Fischer', 'PRON'), ('Fischer', 'NOUN'))],
#  [('of', 'ADP'), (('Psychiatry', 'PRON'), ('Psychiatry', 'NOUN'))],
#  [('Psychiatry', 'NOUN'), (('Johns', 'PRON'), ('Johns', 'NOUN'))],
#  [('Johns', 'NOUN'), (('Hopkins', 'PRON'), ('Hopkins', 'NOUN'))],
#  [("'s", 'PRT'), (('nervousness', 'PRON'), ('nervousness', 'NOUN'))],
#  [('Ministry', 'NOUN'), (('devoted', 'PRON'), ('devoted', 'VERB'))],
#  [(',', '.'), (('half-hour', 'NOUN'), ('half-hour', 'ADJ'))],
#  [('half-hour', 'ADJ'), (('briefing', 'PRON'), ('briefing', 'NOUN'))],
#  [('foreign', 'ADJ'), (('journalists', 'PRON'), ('journalists', 'NOUN'))],
#  [('the', 'DET'), (('subject', 'ADJ'), ('subject', 'NOUN'))],
#  [(',', '.'), (('acquisition-minded', 'PRON'), ('acquisition-minded', 'ADJ'))],
#  [('London-based', 'ADJ'), (('jeweler', 'PRON'), ('jeweler', 'NOUN'))],
#  [('for', 'ADP'), (('Seattle-based', 'PRON'), ('Seattle-based', 'ADJ'))],
#  [('specialty', 'NOUN'), (('jeweler', 'PRON'), ('jeweler', 'NOUN'))],
#  [('$', '.'), (('57.50', 'PRON'), ('57.50', 'NUM'))],
#  [('$', '.'), (('62.1', 'PRON'), ('62.1', 'NUM'))],
#  [('to', 'PRT'), (('outbid', 'PRON'), ('outbid', 'VERB'))],
#  [('.', '.'), (('Sumitomo', 'PRON'), ('Sumitomo', 'NOUN'))],
#  [('Sumitomo', 'NOUN'), (('Metal', 'PRON'), ('Metal', 'NOUN'))],
#  [('to', 'PRT'), (('692', 'PRON'), ('692', 'NUM'))],
#  [('to', 'PRT'), (('960', 'PRON'), ('960', 'NUM'))],
#  [('$', '.'), (('1.82', 'PRON'), ('1.82', 'NUM'))],
#  [('$', '.'), (('84.29', 'PRON'), ('84.29', 'NUM'))],
#  [('described', 'VERB'), (('*-101', 'PRON'), ('*-101', 'X'))],
#  [('the', 'DET'), (('Fantasy', 'PRON'), ('Fantasy', 'NOUN'))],
#  [('a', 'DET'), (('2,050-passenger', 'PRON'), ('2,050-passenger', 'ADJ'))],
#  [('2,050-passenger', 'ADJ'), (('ship', 'VERB'), ('ship', 'NOUN'))],
#  [('ship', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('was', 'VERB'), (('slated', 'PRON'), ('slated', 'VERB'))],
#  [('and', 'CONJ'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [('chief', 'ADJ'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [("'s", 'PRT'), (('return', 'VERB'), ('return', 'NOUN'))],
#  [('improved', 'VERB'), (('operating', 'VERB'), ('operating', 'NOUN'))],
#  [('operating', 'NOUN'), (('efficiencies', 'PRON'), ('efficiencies', 'NOUN'))],
#  [('the', 'DET'), (('purchasing', 'NOUN'), ('purchasing', 'VERB'))],
#  [('reported', 'VERB'), (('better', 'ADV'), ('better', 'ADJ'))],
#  [('better', 'ADJ'), (('export', 'VERB'), ('export', 'NOUN'))],
#  [('*-1', 'X'), (('asserting', 'PRON'), ('asserting', 'VERB'))],
#  [('a', 'DET'), (('greenmailer', 'PRON'), ('greenmailer', 'NOUN'))],
#  [('to', 'PRT'), (('pressure', 'NOUN'), ('pressure', 'VERB'))],
#  [('The', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('Market', 'NOUN'), (('Value', 'PRON'), ('Value', 'NOUN'))],
#  [('gained', 'VERB'), (('1.56', 'PRON'), ('1.56', 'NUM'))],
#  [('to', 'PRT'), (('372.14', 'PRON'), ('372.14', 'NUM'))],
#  [('*-2', 'X'), (('noticing', 'PRON'), ('noticing', 'VERB'))],
#  [('another', 'DET'), (('only', 'ADJ'), ('only', 'ADV'))],
#  [('they', 'PRON'), (('jostle', 'PRON'), ('jostle', 'VERB'))],
#  [('for', 'ADP'), (('cabs', 'PRON'), ('cabs', 'NOUN'))],
#  [('the', 'DET'), (('mothers', 'PRON'), ('mothers', 'NOUN'))],
#  [('several', 'ADJ'), (('thousand', 'PRON'), ('thousand', 'NUM'))],
#  [("n't", 'ADV'), (('recall', 'PRON'), ('recall', 'VERB'))],
#  [('whose', 'PRON'), (('brand', 'PRON'), ('brand', 'NOUN'))],
#  [('placed', 'VERB'), (('*-40', 'PRON'), ('*-40', 'X'))],
#  [('.', '.'), (('Negotiable', 'PRON'), ('Negotiable', 'ADJ'))],
#  [(',', '.'), (('bank-backed', 'PRON'), ('bank-backed', 'ADJ'))],
#  [('were', 'VERB'), (('tidily', 'PRON'), ('tidily', 'ADV'))],
#  [('for', 'ADP'), (('alleged', 'ADJ'), ('alleged', 'VERB'))],
#  [('steel', 'NOUN'), (('mill', 'PRON'), ('mill', 'NOUN'))],
#  [('$', '.'), (('50.38', 'PRON'), ('50.38', 'NUM'))],
#  [('the', 'DET'), (('leeway', 'PRON'), ('leeway', 'NOUN'))],
#  [('means', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('top', 'ADJ'), ('top', 'VERB'))],
#  [('Peter', 'NOUN'), (('Powers', 'PRON'), ('Powers', 'NOUN'))],
#  [('``', '.'), (('deceptive', 'PRON'), ('deceptive', 'ADJ'))],
#  [('then', 'ADV'), (('overseas', 'ADJ'), ('overseas', 'ADV'))],
#  [('legislation', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('is', 'VERB'), (('unlikely', 'PRON'), ('unlikely', 'ADJ'))],
#  [('the', 'DET'), (('context', 'PRON'), ('context', 'NOUN'))],
#  [('is', 'VERB'), (('characterized', 'PRON'), ('characterized', 'VERB'))],
#  [('to', 'PRT'), (('excise', 'ADJ'), ('excise', 'VERB'))],
#  [('bill', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('are', 'VERB'), (('objectionable', 'PRON'), ('objectionable', 'ADJ'))],
#  [('they', 'PRON'), (('conflict', 'PRON'), ('conflict', 'VERB'))],
#  [('a', 'DET'), (('sharper', 'PRON'), ('sharper', 'ADJ'))],
#  [('*U*', 'X'), (('decline', 'VERB'), ('decline', 'NOUN'))],
#  [('$', '.'), (('86.12', 'PRON'), ('86.12', 'NUM'))],
#  [('Many', 'ADJ'), (('Asians', 'PRON'), ('Asians', 'NOUN'))],
#  [('desirable', 'ADJ'),
#   (('counterweight', 'PRON'), ('counterweight', 'NOUN'))],
#  [('The', 'DET'), (('Internal', 'PRON'), ('Internal', 'NOUN'))],
#  [('who', 'PRON'), (('*T*-123', 'PRON'), ('*T*-123', 'X'))],
#  [('to', 'PRT'), (('report', 'NOUN'), ('report', 'VERB'))],
#  [('report', 'VERB'), (('detailed', 'VERB'), ('detailed', 'ADJ'))],
#  [('who', 'PRON'), (('*T*-124', 'PRON'), ('*T*-124', 'X'))],
#  [('spend', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('on', 'ADP'), (('print', 'VERB'), ('print', 'NOUN'))],
#  [('print', 'NOUN'), (('advertising', 'VERB'), ('advertising', 'NOUN'))],
#  [('since', 'ADP'), (('tightened', 'PRON'), ('tightened', 'VERB'))],
#  [('tightened', 'VERB'), (('controls', 'VERB'), ('controls', 'NOUN'))],
#  [('on', 'ADP'), (('index-related', 'PRON'), ('index-related', 'ADJ'))],
#  [('pharmaceutical', 'ADJ'),
#   (('compositions', 'PRON'), ('compositions', 'NOUN'))],
#  [('cartilage', 'NOUN'), (('defects', 'PRON'), ('defects', 'NOUN'))],
#  [('.', '.'), (('Some', 'DET'), ('Some', 'ADV'))],
#  [('Jack', 'NOUN'), (('Brooks', 'PRON'), ('Brooks', 'NOUN'))],
#  [('they', 'PRON'), (('fear', 'NOUN'), ('fear', 'VERB'))],
#  [('make', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('About', 'ADP'), (('11.6', 'PRON'), ('11.6', 'NUM'))],
#  [('economists', 'NOUN'), (('forecast', 'NOUN'), ('forecast', 'VERB'))],
#  [('%', 'NOUN'), (('rise', 'VERB'), ('rise', 'NOUN'))],
#  [('pickers', 'NOUN'), (('scream', 'PRON'), ('scream', 'VERB'))],
#  [('markets', 'NOUN'), (('decline', 'NOUN'), ('decline', 'VERB'))],
#  [('*-3', 'X'), (('hailing', 'PRON'), ('hailing', 'VERB'))],
#  [('still', 'ADV'), (('abounding', 'PRON'), ('abounding', 'VERB'))],
#  [('*EXP*-1', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('buy', 'VERB'), (("'86", 'PRON'), ("'86", 'NUM'))],
#  [(',', '.'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('as', 'ADP'), (('Opus', 'PRON'), ('Opus', 'NOUN'))],
#  [('and', 'CONJ'), (('Dominus', 'PRON'), ('Dominus', 'NOUN'))],
#  [('.', '.'), (('F.H.', 'PRON'), ('F.H.', 'NOUN'))],
#  [('.', '.'), (('Arraignments', 'PRON'), ('Arraignments', 'NOUN'))],
#  [('fallen', 'VERB'), (('short', 'ADJ'), ('short', 'ADV'))],
#  [('.', '.'), (('First', 'NOUN'), ('First', 'ADJ'))],
#  [('of', 'ADP'), (('prepayment', 'PRON'), ('prepayment', 'NOUN'))],
#  [('rates', 'NOUN'), (('decline', 'NOUN'), ('decline', 'VERB'))],
#  [('such', 'ADJ'), (('prepayment', 'PRON'), ('prepayment', 'NOUN'))],
#  [('prepayment', 'NOUN'), (('forces', 'NOUN'), ('forces', 'VERB'))],
#  [('to', 'PRT'), (('redeploy', 'PRON'), ('redeploy', 'VERB'))],
#  [('questions', 'NOUN'), (('range', 'NOUN'), ('range', 'VERB'))],
#  [('a', 'DET'), (('Maine', 'PRON'), ('Maine', 'NOUN'))],
#  [('Maine', 'NOUN'), (('initiative', 'PRON'), ('initiative', 'NOUN'))],
#  [('Cruise', 'NOUN'), (('missiles', 'PRON'), ('missiles', 'NOUN'))],
#  [('North', 'NOUN'), (('Dakota', 'PRON'), ('Dakota', 'NOUN'))],
#  [('Italian', 'ADJ'), (('biscuit', 'PRON'), ('biscuit', 'NOUN'))],
#  [('D.', 'NOUN'), (('Lazzaroni', 'PRON'), ('Lazzaroni', 'NOUN'))],
#  [('hurt', 'VERB'), (('*-40', 'PRON'), ('*-40', 'X'))],
#  [('by', 'ADP'), (('overproduction', 'PRON'), ('overproduction', 'NOUN'))],
#  [('.', '.'), (('Victor', 'PRON'), ('Victor', 'NOUN'))],
#  [('Stanley', 'NOUN'), (('Fishman', 'PRON'), ('Fishman', 'NOUN'))],
#  [(',', '.'), (('Longwood', 'PRON'), ('Longwood', 'NOUN'))],
#  [('Harold', 'NOUN'), (('Floyd', 'PRON'), ('Floyd', 'NOUN'))],
#  [(';', '.'), (('Amin', 'PRON'), ('Amin', 'NOUN'))],
#  [('Amin', 'NOUN'),
#   (('Jalaalwalikraam', 'PRON'), ('Jalaalwalikraam', 'NOUN'))],
#  [(',', '.'), (('Glenham', 'PRON'), ('Glenham', 'NOUN'))],
#  [('F.', 'NOUN'), (('Knapp', 'PRON'), ('Knapp', 'NOUN'))],
#  [(';', '.'), (('Deborah', 'PRON'), ('Deborah', 'NOUN'))],
#  [('Deborah', 'NOUN'), (('Renee', 'PRON'), ('Renee', 'NOUN'))],
#  [('Francis', 'NOUN'), (('Muscolina', 'PRON'), ('Muscolina', 'NOUN'))],
#  [(',', '.'), (('Palisades', 'PRON'), ('Palisades', 'NOUN'))],
#  [('C.', 'NOUN'), (('Najarian', 'PRON'), ('Najarian', 'NOUN'))],
#  [(',', '.'), (('Minn.', 'PRON'), ('Minn.', 'NOUN'))],
#  [('Robert', 'NOUN'), (('Norwick', 'PRON'), ('Norwick', 'NOUN'))],
#  [(',', '.'), (('Nesconset', 'PRON'), ('Nesconset', 'NOUN'))],
#  [('continued', 'VERB'), (('slack', 'NOUN'), ('slack', 'ADJ'))],
#  [('traditionally', 'ADV'), (('slow', 'VERB'), ('slow', 'ADJ'))],
#  [('in', 'ADP'), (('detail', 'PRON'), ('detail', 'NOUN'))],
#  [('the', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('0', 'X'), (('that', 'ADP'), ('that', 'DET'))],
#  [('.', '.'), (('Packages', 'PRON'), ('Packages', 'NOUN'))],
#  [('*-1', 'X'), (('rewarding', 'PRON'), ('rewarding', 'VERB'))],
#  [(',', '.'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('$', '.'), (('43.875', 'PRON'), ('43.875', 'NUM'))],
#  [('the', 'DET'), (('petulant', 'PRON'), ('petulant', 'ADJ'))],
#  [('an', 'DET'), (('impudent', 'PRON'), ('impudent', 'ADJ'))],
#  [('impudent', 'ADJ'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('Sony', 'NOUN'), (('hosted', 'PRON'), ('hosted', 'VERB'))],
#  [('a', 'DET'), (('Luce', 'PRON'), ('Luce', 'NOUN'))],
#  [('Luce', 'NOUN'), (('Fellowship', 'PRON'), ('Fellowship', 'NOUN'))],
#  [('--', '.'), (('to', 'PRT'), ('to', 'ADP'))],
#  [('takes', 'VERB'), (('places', 'VERB'), ('places', 'NOUN'))],
#  [('to', 'PRT'), (('issue', 'NOUN'), ('issue', 'VERB'))],
#  [('tune', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('my', 'PRON'), (('short-wave', 'PRON'), ('short-wave', 'ADJ'))],
#  [(',', '.'), (('transcribe', 'PRON'), ('transcribe', 'VERB'))],
#  [('that', 'ADP'), (('severance', 'PRON'), ('severance', 'NOUN'))],
#  [('not', 'ADV'), (('staying', 'PRON'), ('staying', 'VERB'))],
#  [("'s", 'PRT'), (('operating', 'VERB'), ('operating', 'NOUN'))],
#  [('the', 'DET'), (('astonishment', 'PRON'), ('astonishment', 'NOUN'))],
#  [('and', 'CONJ'), (('dismay', 'PRON'), ('dismay', 'NOUN'))],
#  [('her', 'PRON'), (('superiors', 'PRON'), ('superiors', 'NOUN'))],
#  [('--', '.'), (('and', 'CONJ'), ('and', 'ADJ'))],
#  [('the', 'DET'), (('unpopularity', 'PRON'), ('unpopularity', 'NOUN'))],
#  [('--', '.'), (('Mrs', 'PRON'), ('Mrs', 'NOUN'))],
#  [('well-known', 'ADJ'),
#   (('detective-story', 'PRON'), ('detective-story', 'NOUN'))],
#  [(',', '.'), (('English', 'NOUN'), ('English', 'ADJ'))],
#  [('English', 'ADJ'), (('novelist', 'PRON'), ('novelist', 'NOUN'))],
#  [('*T*-1', 'X'), (('finds', 'PRON'), ('finds', 'VERB'))],
#  [('its', 'PRON'), (('satisfaction', 'PRON'), ('satisfaction', 'NOUN'))],
#  [('in', 'ADP'), (('mathematical', 'PRON'), ('mathematical', 'ADJ'))],
#  [('mathematical', 'ADJ'),
#   (('completeness', 'PRON'), ('completeness', 'NOUN'))],
#  [('mechanical', 'ADJ'), (('perfection', 'PRON'), ('perfection', 'NOUN'))],
#  [("''", '.'), (('Political', 'PRON'), ('Political', 'ADJ'))],
#  [('can', 'VERB'), (('whipsaw', 'PRON'), ('whipsaw', 'VERB'))],
#  [('they', 'PRON'), (('approach', 'NOUN'), ('approach', 'VERB'))],
#  [('a', 'DET'), (('benevolent', 'PRON'), ('benevolent', 'ADJ'))],
#  [(',', '.'), (('altruistic', 'PRON'), ('altruistic', 'ADJ'))],
#  [('and', 'CONJ'), (('dancing', 'PRON'), ('dancing', 'NOUN'))],
#  [('by', 'ADP'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('.', '.'), (('Individuals', 'PRON'), ('Individuals', 'NOUN'))],
#  [('that', 'ADP'), (('Justice', 'NOUN'), ('Justice', 'ADJ'))],
#  [('IRS', 'NOUN'), (('rarely', 'PRON'), ('rarely', 'ADV'))],
#  [('rarely', 'ADV'), (('acted', 'PRON'), ('acted', 'VERB'))],
#  [('.', '.'), (('Indexing', 'PRON'), ('Indexing', 'NOUN'))],
#  [('stock-market', 'NOUN'), (('barometer', 'PRON'), ('barometer', 'NOUN'))],
#  [("'s", 'VERB'), (('imaginative', 'PRON'), ('imaginative', 'ADJ'))],
#  [('two', 'NUM'), (('octogenarians', 'PRON'), ('octogenarians', 'NOUN'))],
#  [('who', 'PRON'), (('*T*-222', 'PRON'), ('*T*-222', 'X'))],
#  [('a', 'DET'),
#   (('sometimes-exhausting', 'PRON'), ('sometimes-exhausting', 'ADJ'))],
#  [('bells', 'NOUN'), (('sounding', 'PRON'), ('sounding', 'VERB'))],
#  [('many', 'ADJ'), (('belfries', 'PRON'), ('belfries', 'NOUN'))],
#  [('East', 'NOUN'), (('Anglia', 'PRON'), ('Anglia', 'NOUN'))],
#  [('Department', 'NOUN'), (('projects', 'NOUN'), ('projects', 'VERB'))],
#  [('nearly', 'ADV'), (('one-fifth', 'PRON'), ('one-fifth', 'NOUN'))],
#  [('The', 'DET'), (('CEO', 'PRON'), ('CEO', 'NOUN'))],
#  [('CEO', 'NOUN'), (('succession', 'PRON'), ('succession', 'NOUN'))],
#  [('take', 'VERB'), (('early', 'ADV'), ('early', 'ADJ'))],
#  [('will', 'VERB'), (('climb', 'PRON'), ('climb', 'VERB'))],
#  [('from', 'ADP'), (('566.54', 'PRON'), ('566.54', 'NUM'))],
#  [('was', 'VERB'), (('forecast', 'NOUN'), ('forecast', 'VERB'))],
#  [('from', 'ADP'), (('28.53', 'PRON'), ('28.53', 'NUM'))],
#  [('publishes', 'VERB'), (('The', 'DET'), ('The', 'NOUN'))],
#  [(',', '.'), (('Barron', 'PRON'), ('Barron', 'NOUN'))],
#  [('Barron', 'NOUN'), (("'s", 'VERB'), ("'s", 'PRT'))],
#  [('-LRB-', '.'), (('Fewer', 'PRON'), ('Fewer', 'ADJ'))],
#  [(',', '.'), (('T-shirts', 'PRON'), ('T-shirts', 'NOUN'))],
#  [('the', 'DET'), (('corridors', 'PRON'), ('corridors', 'NOUN'))],
#  [('corridors', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('familiar', 'ADJ'), (('red-and-white', 'PRON'), ('red-and-white', 'ADJ'))],
#  [('red-and-white', 'ADJ'), (('GHS', 'PRON'), ('GHS', 'NOUN'))],
#  [('GHS', 'NOUN'), (('logo', 'PRON'), ('logo', 'NOUN'))],
#  [('a', 'DET'), (('Sanford', 'PRON'), ('Sanford', 'NOUN'))],
#  [('the', 'DET'), (('ranks', 'PRON'), ('ranks', 'NOUN'))],
#  [('*-1', 'X'), (('demonstrating', 'PRON'), ('demonstrating', 'VERB'))],
#  [('a', 'DET'), (('raw', 'PRON'), ('raw', 'ADJ'))],
#  [('he', 'PRON'), (('possessed', 'PRON'), ('possessed', 'VERB'))],
#  [('%', 'NOUN'), (('upturn', 'PRON'), ('upturn', 'NOUN'))],
#  [('more', 'ADJ'), (('couples', 'PRON'), ('couples', 'NOUN'))],
#  [('*ICH*-1', 'X'), (('exchanging', 'PRON'), ('exchanging', 'VERB'))],
#  [('exchanging', 'VERB'), (('rings', 'VERB'), ('rings', 'NOUN'))],
#  [('``', '.'), (('Professional', 'NOUN'), ('Professional', 'ADJ'))],
#  [('get', 'VERB'), (('enough', 'ADV'), ('enough', 'ADJ'))],
#  [('$', '.'), (('55-a-share', 'PRON'), ('55-a-share', 'ADJ'))],
#  [('*U*', 'X'), (('bid', 'VERB'), ('bid', 'NOUN'))],
#  [('bid', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [(',', '.'), (('steps', 'NOUN'), ('steps', 'VERB'))],
#  [('LONDON', 'NOUN'), (('INTERBANK', 'PRON'), ('INTERBANK', 'NOUN'))],
#  [('INTERBANK', 'NOUN'), (('OFFERED', 'PRON'), ('OFFERED', 'VERB'))],
#  [('-LRB-', '.'), (('LIBOR', 'PRON'), ('LIBOR', 'NOUN'))],
#  [('.', '.'), (('LANDOR', 'PRON'), ('LANDOR', 'NOUN'))],
#  [('LANDOR', 'NOUN'), (('ASSOCIATES', 'PRON'), ('ASSOCIATES', 'NOUN'))],
#  [('would', 'VERB'), (('destroy', 'PRON'), ('destroy', 'VERB'))],
#  [('pricing', 'NOUN'), (('efficiency', 'PRON'), ('efficiency', 'NOUN'))],
#  [('was', 'VERB'), (('47.1', 'PRON'), ('47.1', 'NUM'))],
#  [('and', 'CONJ'), (('entertaining', 'PRON'), ('entertaining', 'ADJ'))],
#  [('that', 'DET'), (('means', 'NOUN'), ('means', 'VERB'))],
#  [('means', 'VERB'),
#   (('confrontational', 'PRON'), ('confrontational', 'ADJ'))],
#  [('.', '.'), (('Atsushi', 'PRON'), ('Atsushi', 'NOUN'))],
#  [('Atsushi', 'NOUN'), (('Muramatsu', 'PRON'), ('Muramatsu', 'NOUN'))],
#  [(',', '.'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('has', 'VERB'), (('experienced', 'PRON'), ('experienced', 'VERB'))],
#  [('a', 'DET'), (('remarkable', 'PRON'), ('remarkable', 'ADJ'))],
#  [('many', 'ADJ'), (('difficulties', 'PRON'), ('difficulties', 'NOUN'))],
#  [('no', 'DET'), (('bearing', 'VERB'), ('bearing', 'NOUN'))],
#  [('our', 'PRON'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('work', 'NOUN'), (('force', 'VERB'), ('force', 'NOUN'))],
#  [('in', 'ADP'), (('limbo', 'PRON'), ('limbo', 'NOUN'))],
#  [('which', 'DET'), (('*T*-195', 'PRON'), ('*T*-195', 'X'))],
#  [(',', '.'), (('fueling', 'PRON'), ('fueling', 'NOUN'))],
#  [('and', 'CONJ'), (('airports', 'PRON'), ('airports', 'NOUN'))],
#  [('its', 'PRON'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('recent', 'ADJ'), (('fiscal', 'ADJ'), ('fiscal', 'NOUN'))],
#  [('the', 'DET'), (('past', 'ADJ'), ('past', 'NOUN'))],
#  [('an', 'DET'), (('individual', 'ADJ'), ('individual', 'NOUN'))],
#  [('its', 'PRON'), (('Eveready', 'PRON'), ('Eveready', 'NOUN'))],
#  [('the', 'DET'), (('diverse', 'PRON'), ('diverse', 'ADJ'))],
#  [('diverse', 'ADJ'), (('showing', 'VERB'), ('showing', 'NOUN'))],
#  [('only', 'ADV'), (('enhances', 'PRON'), ('enhances', 'VERB'))],
#  [('the', 'DET'), (('importance', 'PRON'), ('importance', 'NOUN'))],
#  [('of', 'ADP'), (('rusted', 'PRON'), ('rusted', 'VERB'))],
#  [('oil', 'NOUN'), (('drums', 'PRON'), ('drums', 'NOUN'))],
#  [('drums', 'NOUN'), (('swim', 'PRON'), ('swim', 'VERB'))],
#  [('voice', 'NOUN'), (('purrs', 'PRON'), ('purrs', 'VERB'))],
#  [('the', 'DET'), (('neighbors', 'PRON'), ('neighbors', 'NOUN'))],
#  [('I', 'PRON'), (('sense', 'NOUN'), ('sense', 'VERB'))],
#  [('are', 'VERB'), (('reluctant', 'PRON'), ('reluctant', 'ADJ'))],
#  [('to', 'PRT'), (('stick', 'PRON'), ('stick', 'VERB'))],
#  [('their', 'PRON'), (('necks', 'PRON'), ('necks', 'NOUN'))],
#  [('come', 'VERB'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('Richard', 'NOUN'), (('Eakle', 'PRON'), ('Eakle', 'NOUN'))],
#  [('of', 'ADP'), (('Eakle', 'PRON'), ('Eakle', 'NOUN'))],
#  [('a', 'DET'), (('deluge', 'PRON'), ('deluge', 'NOUN'))],
#  [('was', 'VERB'), (('abuzz', 'PRON'), ('abuzz', 'ADJ'))],
#  [('The', 'DET'), (('parishioners', 'PRON'), ('parishioners', 'NOUN'))],
#  [('All', 'DET'), (('Angels', 'PRON'), ('Angels', 'NOUN'))],
#  [('to', 'PRT'), (('chat', 'PRON'), ('chat', 'VERB'))],
#  [(',', '.'), (('billed', 'PRON'), ('billed', 'VERB'))],
#  [('``', '.'), (('The', 'DET'), ('The', 'NOUN'))],
#  [('The', 'NOUN'), (('Practical', 'PRON'), ('Practical', 'NOUN'))],
#  [('the', 'DET'), (('Environment', 'PRON'), ('Environment', 'NOUN'))],
#  [('the', 'DET'), (('Japanese', 'ADJ'), ('Japanese', 'NOUN'))],
#  [('playing', 'VERB'), (('catch-up', 'PRON'), ('catch-up', 'NOUN'))],
#  [('.', '.'), (('Compromises', 'PRON'), ('Compromises', 'NOUN'))],
#  [('For', 'ADP'), (('starters', 'PRON'), ('starters', 'NOUN'))],
#  [('H.', 'NOUN'), (('Hudnut', 'PRON'), ('Hudnut', 'NOUN'))],
#  [('Indianapolis', 'NOUN'), (('Symphony', 'PRON'), ('Symphony', 'NOUN'))],
#  [('Symphony', 'NOUN'), (('Orchestra', 'PRON'), ('Orchestra', 'NOUN'))],
#  [('a', 'DET'), (('guest', 'PRON'), ('guest', 'NOUN'))],
#  [('guest', 'NOUN'),
#   (('pianist-comedian', 'PRON'), ('pianist-comedian', 'NOUN'))],
#  [('pianist-comedian', 'NOUN'), (('Victor', 'PRON'), ('Victor', 'NOUN'))],
#  [('Victor', 'NOUN'), (('Borge', 'PRON'), ('Borge', 'NOUN'))],
#  [('*U*', 'X'), (('gain', 'VERB'), ('gain', 'NOUN'))],
#  [('Florio', 'NOUN'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('goes', 'VERB'), (('on', 'ADP'), ('on', 'PRT'))],
#  [("'s", 'PRT'), (('land', 'VERB'), ('land', 'NOUN'))],
#  [('was', 'VERB'), (('cleaned', 'PRON'), ('cleaned', 'VERB'))],
#  [('no', 'DET'), (('pollution', 'PRON'), ('pollution', 'NOUN'))],
#  [('a', 'DET'), (('definitive', 'PRON'), ('definitive', 'ADJ'))],
#  [('$', '.'), (('57.50', 'PRON'), ('57.50', 'NUM'))],
#  [('.', '.'), (('Follow-up', 'PRON'), ('Follow-up', 'ADJ'))],
#  [('Follow-up', 'ADJ'), (('report', 'VERB'), ('report', 'NOUN'))],
#  [('South', 'NOUN'), (('Africa', 'PRON'), ('Africa', 'NOUN'))],
#  [('accused', 'VERB'), (('armed', 'PRON'), ('armed', 'VERB'))],
#  [('armed', 'VERB'), (('Namibian', 'PRON'), ('Namibian', 'ADJ'))],
#  [('Namibian', 'ADJ'), (('nationalist', 'PRON'), ('nationalist', 'ADJ'))],
#  [('nationalist', 'ADJ'), (('guerrillas', 'PRON'), ('guerrillas', 'NOUN'))],
#  [('in', 'ADP'), (('neighboring', 'PRON'), ('neighboring', 'VERB'))],
#  [('neighboring', 'VERB'), (('Angola', 'PRON'), ('Angola', 'NOUN'))],
#  [('*-1', 'X'), (('violating', 'PRON'), ('violating', 'VERB'))],
#  [('violating', 'VERB'),
#   (('U.N.-supervised', 'PRON'), ('U.N.-supervised', 'ADJ'))],
#  [('U.N.-supervised', 'ADJ'), (('peace', 'PRON'), ('peace', 'NOUN'))],
#  [('peace', 'NOUN'), (('plans', 'VERB'), ('plans', 'NOUN'))],
#  [('the', 'DET'), (('territory', 'PRON'), ('territory', 'NOUN'))],
#  [('territory', 'NOUN'), (("'s", 'VERB'), ("'s", 'PRT'))],
#  [('its', 'PRON'), (('offer', 'VERB'), ('offer', 'NOUN'))],
#  [('*-2', 'X'), (('agreeing', 'PRON'), ('agreeing', 'VERB'))],
#  [('El', 'NOUN'), (('Paso', 'PRON'), ('Paso', 'NOUN'))],
#  [('Western', 'ADJ'), (('boots', 'PRON'), ('boots', 'NOUN'))],
#  [('and', 'CONJ'), (('leather', 'PRON'), ('leather', 'NOUN'))],
#  [('the', 'DET'), (('preferred', 'ADJ'), ('preferred', 'VERB'))],
#  [('would', 'VERB'), (('accrue', 'PRON'), ('accrue', 'VERB'))],
#  [('will', 'VERB'), (('travel', 'NOUN'), ('travel', 'VERB'))],
#  [('other', 'ADJ'), (('Soviet', 'NOUN'), ('Soviet', 'ADJ'))],
#  [('The', 'DET'), (('Japanese', 'ADJ'), ('Japanese', 'NOUN'))],
#  [('Japanese', 'NOUN'), (('fret', 'PRON'), ('fret', 'NOUN'))],
#  [("'s", 'PRT'), (('rancor', 'PRON'), ('rancor', 'NOUN'))],
#  [('activities', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('``', '.'), (('*T*-137', 'PRON'), ('*T*-137', 'X'))],
#  [('or', 'CONJ'), (('advocate', 'PRON'), ('advocate', 'VERB'))],
#  [("''", '.'), (('Strong', 'PRON'), ('Strong', 'ADJ'))],
#  [('black', 'ADJ'), (('widow', 'PRON'), ('widow', 'NOUN'))],
#  [('of', 'ADP'), (('valuation', 'PRON'), ('valuation', 'NOUN'))],
#  [('a', 'DET'), (('reference', 'PRON'), ('reference', 'NOUN'))],
#  [('female', 'ADJ'), (('spiders', 'PRON'), ('spiders', 'NOUN'))],
#  [('spiders', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-231', 'PRON'), ('*T*-231', 'X'))],
#  [('attract', 'VERB'), (('males', 'PRON'), ('males', 'NOUN'))],
#  [('after', 'ADP'), (('mating', 'PRON'), ('mating', 'VERB'))],
#  [('.', '.'), (('Fourteen', 'PRON'), ('Fourteen', 'NUM'))],
#  [('with', 'ADP'), (('jurisdiction', 'PRON'), ('jurisdiction', 'NOUN'))],
#  [('the', 'DET'), (('EEOC', 'PRON'), ('EEOC', 'NOUN'))],
#  [('his', 'PRON'), (('judgment', 'PRON'), ('judgment', 'NOUN'))],
#  [('The', 'DET'), (("'82", 'PRON'), ("'82", 'NUM'))],
#  [('lying', 'VERB'), (('down', 'ADV'), ('down', 'ADP'))],
#  [('for', 'ADP'), (('long', 'ADJ'), ('long', 'ADV'))],
#  [(',', '.'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('of', 'ADP'), (('marketing', 'NOUN'), ('marketing', 'VERB'))],
#  [('been', 'VERB'), (('spending', 'NOUN'), ('spending', 'VERB'))],
#  [('their', 'PRON'), (('images', 'PRON'), ('images', 'NOUN'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [("'s", 'PRT'), (('perceptions', 'PRON'), ('perceptions', 'NOUN'))],
#  [('0', 'X'), (('greedy', 'PRON'), ('greedy', 'ADJ'))],
#  [('market', 'NOUN'), (('manipulators', 'PRON'), ('manipulators', 'NOUN'))],
#  [('a', 'DET'), (('shambles', 'PRON'), ('shambles', 'NOUN'))],
#  [("'s", 'PRT'), (('free-enterprise', 'PRON'), ('free-enterprise', 'NOUN'))],
#  [('big', 'ADJ'), (('gambling', 'PRON'), ('gambling', 'NOUN'))],
#  [('gambling', 'NOUN'), (('den', 'PRON'), ('den', 'NOUN'))],
#  [('the', 'DET'), (('odds', 'PRON'), ('odds', 'NOUN'))],
#  [('heavily', 'ADV'), (('stacked', 'PRON'), ('stacked', 'VERB'))],
#  [('replace', 'VERB'), (('British', 'ADJ'), ('British', 'NOUN'))],
#  [('British', 'NOUN'), (('Airways', 'PRON'), ('Airways', 'NOUN'))],
#  [('of', 'ADP'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [(',', '.'), (('dominates', 'PRON'), ('dominates', 'VERB'))],
#  [('the', 'DET'), (('flightiness', 'PRON'), ('flightiness', 'NOUN'))],
#  [('will', 'VERB'), (('diminish', 'PRON'), ('diminish', 'VERB'))],
#  [('the', 'DET'), (('ranks', 'PRON'), ('ranks', 'NOUN'))],
#  [('the', 'DET'), (('East', 'NOUN'), ('East', 'ADJ'))],
#  [('East', 'ADJ'), (('Anglian', 'PRON'), ('Anglian', 'ADJ'))],
#  [('group', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-223', 'PRON'), ('*T*-223', 'X'))],
#  [('bells', 'NOUN'), (('pealing', 'PRON'), ('pealing', 'VERB'))],
#  [('to', 'PRT'), (('292.32', 'PRON'), ('292.32', 'NUM'))],
#  [('from', 'ADP'), (('263.07', 'PRON'), ('263.07', 'NUM'))],
#  [(',', '.'), (('publishing', 'NOUN'), ('publishing', 'VERB'))],
#  [('publishing', 'VERB'),
#   (('entrepreneur', 'PRON'), ('entrepreneur', 'NOUN'))],
#  [('entrepreneur', 'NOUN'), (('Patricia', 'PRON'), ('Patricia', 'NOUN'))],
#  [('straight', 'ADJ'), (('scoop', 'VERB'), ('scoop', 'NOUN'))],
#  [('*', 'X'), (('SWITCHING', 'PRON'), ('SWITCHING', 'VERB'))],
#  [('SWITCHING', 'VERB'), (('TO', 'PRON'), ('TO', 'PRT'))],
#  [('THE', 'DET'), (('DEFENSE', 'PRON'), ('DEFENSE', 'NOUN'))],
#  [('a', 'DET'), (('slowing', 'NOUN'), ('slowing', 'VERB'))],
#  [("n't", 'ADV'), (('signaling', 'PRON'), ('signaling', 'VERB'))],
#  [('at', 'ADP'), (('Pitney', 'PRON'), ('Pitney', 'NOUN'))],
#  [('Pitney', 'NOUN'), (('Bowes', 'PRON'), ('Bowes', 'NOUN'))],
#  [('$', '.'), (('110', 'PRON'), ('110', 'NUM'))],
#  [('$', '.'), (('282', 'PRON'), ('282', 'NUM'))],
#  [('of', 'ADP'), (('multinational', 'PRON'), ('multinational', 'ADJ'))],
#  [('to', 'PRT'), (('repay', 'PRON'), ('repay', 'VERB'))],
#  [('.', '.'), (('Showa', 'PRON'), ('Showa', 'NOUN'))],
#  [('Showa', 'NOUN'), (('Shell', 'PRON'), ('Shell', 'NOUN'))],
#  [('to', 'PRT'), (('1,570', 'PRON'), ('1,570', 'NUM'))],
#  [('quite', 'ADV'), (('content', 'NOUN'), ('content', 'ADJ'))],
#  [('third-quarter', 'NOUN'), (('net', 'NOUN'), ('net', 'ADJ'))],
#  [('$', '.'), (('35.2', 'PRON'), ('35.2', 'NUM'))],
#  [('to', 'PRT'), (('favor', 'NOUN'), ('favor', 'VERB'))],
#  [('included', 'VERB'), (('checking', 'NOUN'), ('checking', 'VERB'))],
#  [(',', '.'), (('safe', 'PRON'), ('safe', 'ADJ'))],
#  [('--', '.'), (('plus', 'CONJ'), ('plus', 'ADV'))],
#  [('Patrick', 'NOUN'), (('Mannix', 'PRON'), ('Mannix', 'NOUN'))],
#  [('to', 'PRT'), (('trash', 'PRON'), ('trash', 'VERB'))],
#  [('D.', 'NOUN'), (('Carney', 'PRON'), ('Carney', 'NOUN'))],
#  [('The', 'DET'), (('Nicaraguan', 'PRON'), ('Nicaraguan', 'ADJ'))],
#  [('the', 'DET'), (('U.S.-backed', 'PRON'), ('U.S.-backed', 'ADJ'))],
#  [('a', 'DET'), (('19-month-old', 'PRON'), ('19-month-old', 'ADJ'))],
#  [('19-month-old', 'ADJ'), (('cease-fire', 'PRON'), ('cease-fire', 'NOUN'))],
#  [("''", '.'), (('FAMILY', 'PRON'), ('FAMILY', 'NOUN'))],
#  [('FAMILY', 'NOUN'), (('PETS', 'PRON'), ('PETS', 'NOUN'))],
#  [('improving', 'VERB'), (('recovery', 'PRON'), ('recovery', 'NOUN'))],
#  [(',', '.'), (('Milwaukee', 'PRON'), ('Milwaukee', 'NOUN'))],
#  [('a', 'DET'), (('double-A', 'PRON'), ('double-A', 'ADJ'))],
#  [('$', '.'), (('963', 'PRON'), ('963', 'NUM'))],
#  [('In', 'ADP'), (('reference', 'PRON'), ('reference', 'NOUN'))],
#  [('9', 'NUM'), (('page-one', 'ADJ'), ('page-one', 'NOUN'))],
#  [('``', '.'), (('Barbara', 'PRON'), ('Barbara', 'NOUN'))],
#  [('Bush', 'NOUN'), (('Earns', 'PRON'), ('Earns', 'VERB'))],
#  [('Higher', 'ADJ'), (('Ratings', 'PRON'), ('Ratings', 'NOUN'))],
#  [('Ratings', 'NOUN'), (('Than', 'PRON'), ('Than', 'ADP'))],
#  [('is', 'VERB'), (('regrettable', 'PRON'), ('regrettable', 'ADJ'))],
#  [('our', 'PRON'), (('negatives', 'PRON'), ('negatives', 'NOUN'))],
#  [('Among', 'ADP'), (('liberals', 'PRON'), ('liberals', 'NOUN'))],
#  [('weeks', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('the', 'DET'), (('reservoirs', 'PRON'), ('reservoirs', 'NOUN'))],
#  [('reservoirs', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('.', '.'), (('Homeless', 'NOUN'), ('Homeless', 'ADJ'))],
#  [('not', 'ADV'), (('only', 'ADV'), ('only', 'ADJ'))],
#  [('only', 'ADJ'), (('lack', 'NOUN'), ('lack', 'VERB'))],
#  [('also', 'ADV'), (('lack', 'NOUN'), ('lack', 'VERB'))],
#  [('the', 'DET'), (('elementary', 'PRON'), ('elementary', 'ADJ'))],
#  [('elementary', 'ADJ'), (('necessities', 'PRON'), ('necessities', 'NOUN'))],
#  [('of', 'ADP'), (('nutrition', 'PRON'), ('nutrition', 'NOUN'))],
#  [(',', '.'), (('cleanliness', 'PRON'), ('cleanliness', 'NOUN'))],
#  [('health', 'NOUN'), (('care', 'VERB'), ('care', 'NOUN'))],
#  [('it', 'PRON'), (('resists', 'PRON'), ('resists', 'VERB'))],
#  [('a', 'DET'), (('following', 'VERB'), ('following', 'NOUN'))],
#  [('$', '.'), (('98.3', 'PRON'), ('98.3', 'NUM'))],
#  [('*U*', 'X'), (('promissory', 'PRON'), ('promissory', 'ADJ'))],
#  [('promissory', 'ADJ'), (('note', 'VERB'), ('note', 'NOUN'))],
#  [('will', 'VERB'), (('complicate', 'PRON'), ('complicate', 'VERB'))],
#  [('a', 'DET'), (('valuation', 'PRON'), ('valuation', 'NOUN'))],
#  [('*', 'X'), (('Winning', 'PRON'), ('Winning', 'VERB'))],
#  [("n't", 'ADV'), (('that', 'ADP'), ('that', 'ADV'))],
#  [('So', 'ADV'), (('Long', 'NOUN'), ('Long', 'ADJ'))],
#  [(',', '.'), (('L.A.', 'PRON'), ('L.A.', 'NOUN'))],
#  [('final', 'ADJ'), (('headline', 'PRON'), ('headline', 'NOUN'))],
#  [('be', 'VERB'), (('real', 'ADJ'), ('real', 'ADV'))],
#  [('*', 'X'), (('photocopying', 'PRON'), ('photocopying', 'VERB'))],
#  [('the', 'DET'), (('Anti-Deficiency', 'PRON'), ('Anti-Deficiency', 'NOUN'))],
#  [('prohibits', 'VERB'), (('voluntary', 'PRON'), ('voluntary', 'ADJ'))],
#  [('*', 'X'), (('calculated', 'PRON'), ('calculated', 'VERB'))],
#  [('International', 'NOUN'),
#   (('Perspective', 'PRON'), ('Perspective', 'NOUN'))],
#  [(',', '.'), (('Geneva', 'PRON'), ('Geneva', 'NOUN'))]]

# %%
len(incorrect_tagged_cases)
# Out:
# 486

# %% [markdown]
# ### Tokenizing the sentences in the test file

# %%
## Preparing data for the test file and its sentences
sentence_test ='Android is a mobile operating system developed by Google.Android has been the best-selling OS worldwide on smartphones since 2011 and on tablets since 2013.Google and Twitter made a deal in 2015 that gave Google access to Twitter firehose.Twitter is an online news and social networking service on which users post and interact with messages known as tweets.Before entering politics, Donald Trump was a domineering businessman and a television personality.The 2018 FIFA World Cup is the 21st FIFA World Cup, an international football tournament contested once every four years.This is the first World Cup to be held in Eastern Europe and the 11th time that it has been held in Europe.Show me the cheapest round trips from Dallas to Atlanta.I would like to see flights from Denver to Philadelphia.Show me the price of the flights leaving Atlanta at about 3 in the afternoon and arriving in San Francisco.NASA invited social media users to experience the launch of ICESAT-2 Satellite.'
sentence_test_split = sentence_test.split()
words = word_tokenize(sentence_test)

# %% [markdown]
# # Statistics of vanilla Viterbi algorithm
# #### 486 words have been incorrectly tagged and are unknown words
# #### Accuracy is 89.6%

# %% [markdown]
# # Solve the problem of unknown words

# %% [markdown]
# # Now we will use two techniques to modify the vanilla Viterbi algorithm - First by using Unigram Tagger and then by using the combination of Unigram,Bigram and Rule Based(Morphing) Taggers.The functions created are unigram() and morph() which is called from inside the Vitrebi function and return accuracies of Viterbi,Unigram and morph functions.

# %% [markdown]
# ### unigram Function - returns accuracy of tagging for the same input as vanilla Viterbi

# %%
def unigram(data):
    unigram_tagger = nltk.UnigramTagger(train_set)
    accuracy = unigram_tagger.evaluate(data)
    return accuracy

# %% [markdown]
# ### morph function - returns accuracy of tagging for the same input as vanilla Viterbi.Also returns the tags for thesentences given in the testing file

# %%
def morph(data_input,test_sent):

    patterns = [
        (r'.*ing$', 'VERB'),
        (r'(The|the|A|a|An|an|some|Some|most|Most|every|Every|no|No)$', 'DET'),
        (r'(To|to|In|in)$', 'ADP'),# gerund
        (r'(I|i|you|You|he|He|she|She|it|It|we|We|they|They)$', 'PRON'),
        (r'(and|And|or|Or|but|But)$', 'CONJ'),
        (r'.*ed$', 'VERB'),               # past tense
        (r'.*es$', 'VERB'),
        (r'.*able$', 'ADJ'),
        (r'.*ness$', 'NOUN'),
        (r'.*s$', 'NOUN'),  
        (r'.*ly$', 'ADV'),# 3rd singular present
        (r'^-?[0-9]+(.[0-9]+)?$', 'NUM'), # cardinal numbers
        (r'^[A-Z]','NOUN'),
        (r'.*', 'NOUN')                    # nouns
    
         ]
#Rule-Based (Regular Expression) Tagger

    rule_based_tagger = nltk.RegexpTagger(patterns)

# lexicon backed up by the rule-based tagger
    lexicon_tagger = nltk.UnigramTagger(train_set, backoff=rule_based_tagger)

# Bigram backed up by the lexicon tagger
    bigram_tagger = nltk.BigramTagger(train_set, backoff=lexicon_tagger)

    accuracy = bigram_tagger.evaluate(data_input)
    tag = bigram_tagger.tag(test_sent)

    return (accuracy,tag)

# %% [markdown]
# ### Modification to original vanilla Viterbi funtion by implementing two techniques to deal with unknown words.

# %%
# Modified Viterbi Heuristic
def Viterbi_Mod(words,sentence,train_bag = train_tagged_words):
    state = []
    #unigram_tagger = nltk.UnigramTagger(train_set)

    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            count_w_given_tag, count_tag = word_given_tag(words[key], tag)
            emission_p = count_w_given_tag/count_tag
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
        tagged = list(zip(words, state))
        check = [i for i, j in zip(tagged, test_run_base) if i == j] 
        accuracy = len(check)/len(tagged)
    
               
# Call the unigram function to check accuracy of tagged words - Technique 1  
    unigram_accuracy = unigram(sentence)

# Call the morph function to check accuracy of tagged words - Technique 2         
    morph_data = morph(sentence,sentence_test_split)
    morph_list = [morph_data]

    #morph accuracy
    morph_select_accuracy = [i[0] for i in morph_list]
    morph_accuracy = morph_select_accuracy[0]
    
    #morph Tag
    morph_select_tag = [i[1] for i in morph_list]
    morph_tagging = morph_select_tag[0]           
    
    return (accuracy,unigram_accuracy,morph_accuracy,morph_tagging)

# %%
# tagging the test sentences
start = time.time()
tagged_mod_seq = Viterbi_Mod(test_tagged_words,test_set)
end = time.time()
difference = end-start

# %% [markdown]
# ### Comparing the tagging accuracies of the modifications with the vanilla Viterbi algorithm

# %%
print('The accuracy for vanilla Viterbi is :',tagged_mod_seq[0])
print('The accuracy for unigram tagger is :',tagged_mod_seq[1])
print('The accuracy for combination tagger is :',tagged_mod_seq[2])
# Out:
# The accuracy for vanilla Viterbi is : 0.8960872354073124
# The accuracy for unigram tagger is : 0.8945905494975411
# The accuracy for combination tagger is : 0.9506093649775497

# %% [markdown]
# ### The modification technique 2 - backoff using bigram,unigram and rule based perfomed with better accuracy (95%) compared to unigram technique 1 (89.4%).Unigram had the same accuracy as that of Viterbi

# %% [markdown]
# # We now see how the vanilla Viterbi and modification perform on the given test file given.

# %% [markdown]
# ### Applying vanilla Viterbi to the test sentences.

# %%
tagged_test_seq = Viterbi(words,words)
print(tagged_test_seq)
# Out:
# [('Android', 'PRON'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google.Android', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', 'PRON'), ('worldwide', 'PRON'), ('on', 'ADP'), ('smartphones', 'PRON'), ('since', 'ADP'), ('2011', 'PRON'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013.Google', 'PRON'), ('and', 'CONJ'), ('Twitter', 'PRON'), ('made', 'VERB'), ('a', 'DET'), ('deal', 'NOUN'), ('in', 'ADP'), ('2015', 'PRON'), ('that', 'ADP'), ('gave', 'VERB'), ('Google', 'PRON'), ('access', 'NOUN'), ('to', 'PRT'), ('Twitter', 'PRON'), ('firehose.Twitter', 'PRON'), ('is', 'VERB'), ('an', 'DET'), ('online', 'PRON'), ('news', 'NOUN'), ('and', 'CONJ'), ('social', 'ADJ'), ('networking', 'NOUN'), ('service', 'NOUN'), ('on', 'ADP'), ('which', 'DET'), ('users', 'NOUN'), ('post', 'NOUN'), ('and', 'CONJ'), ('interact', 'PRON'), ('with', 'ADP'), ('messages', 'PRON'), ('known', 'VERB'), ('as', 'ADP'), ('tweets.Before', 'PRON'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', 'PRON'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality.The', 'PRON'), ('2018', 'PRON'), ('FIFA', 'PRON'), ('World', 'NOUN'), ('Cup', 'PRON'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'PRON'), ('FIFA', 'PRON'), ('World', 'NOUN'), ('Cup', 'PRON'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'PRON'), ('contested', 'PRON'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years.This', 'PRON'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', 'PRON'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe.Show', 'PRON'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'PRON'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta.I', 'PRON'), ('would', 'VERB'), ('like', 'ADP'), ('to', 'PRT'), ('see', 'VERB'), ('flights', 'NOUN'), ('from', 'ADP'), ('Denver', 'NOUN'), ('to', 'PRT'), ('Philadelphia.Show', 'PRON'), ('me', 'PRON'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('flights', 'NOUN'), ('leaving', 'VERB'), ('Atlanta', 'NOUN'), ('at', 'ADP'), ('about', 'ADP'), ('3', 'NUM'), ('in', 'ADP'), ('the', 'DET'), ('afternoon', 'NOUN'), ('and', 'CONJ'), ('arriving', 'PRON'), ('in', 'ADP'), ('San', 'NOUN'), ('Francisco.NASA', 'PRON'), ('invited', 'PRON'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', 'PRON'), ('Satellite', 'PRON'), ('.', '.')]

# %%
len(tagged_test_seq)
# Out:
# 161

# %% [markdown]
# ### Picking 3 elements that have been incorrectly tagged by vanilla Viterbi

# %%
from operator import itemgetter
itemgetter(0,158,159)(tagged_test_seq)
# Out:
# (('Android', 'PRON'), ('ICESAT-2', 'PRON'), ('Satellite', 'PRON'))

# %%
len(tagged_mod_seq[3])
# Out:
# 158

# %% [markdown]
# ### The correct tagging of the three elements after applying the modification technique 2 - Combined tagger (unigram,bigram and rule based)

# %%
from operator import itemgetter
itemgetter(0,156,157)(tagged_mod_seq[3])
# Out:
# (('Android', 'NOUN'), ('ICESAT-2', 'NOUN'), ('Satellite.', 'NOUN'))

# %% [markdown]
# ### Comparing the three elements from test sentence between Viterbi and Modified tagger

# %%
from operator import itemgetter
print('Incorrectly tagged by Viterbi :',itemgetter(0,158,159)(tagged_test_seq))
print('\n')
print('Correctly tagged by the Modified Combined Tagger :',itemgetter(0,156,157)(tagged_mod_seq[3]))
# Out:
# Incorrectly tagged by Viterbi : (('Android', 'PRON'), ('ICESAT-2', 'PRON'), ('Satellite', 'PRON'))
#
#
# Correctly tagged by the Modified Combined Tagger : (('Android', 'NOUN'), ('ICESAT-2', 'NOUN'), ('Satellite.', 'NOUN'))
