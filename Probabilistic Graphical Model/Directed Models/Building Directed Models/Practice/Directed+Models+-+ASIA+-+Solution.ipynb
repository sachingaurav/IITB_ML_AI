# %% [markdown]
# ## Making Inferences in the ASIA graph

# %% [markdown]
# Notebook layout:
# 1. Load ASIA model
# 2. Make inferences

# %% [markdown]
# ## Graph
# ![ASIA Graph](resources/ASIA.jpg)

# %% [markdown]
# ## 1. Load ASIA Model

# %%
# import essential libraries to manipulate data
import numpy as np
import pandas as pd

# import pgmpy functions
from pgmpy.readwrite import BIFReader
from pgmpy.inference import VariableElimination

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# load model
data = BIFReader('asia.bif')
asia_model = data.get_model()

# %%
# print nodes of the model
asia_model.nodes()
# Out:
# NodeView(('asia', 'tub', 'smoke', 'lung', 'bronc', 'either', 'xray', 'dysp'))

# %%
# print edges of the model
asia_model.edges()
# Out:
# OutEdgeView([('asia', 'tub'), ('tub', 'either'), ('smoke', 'lung'), ('smoke', 'bronc'), ('lung', 'either'), ('bronc', 'dysp'), ('either', 'xray'), ('either', 'dysp')])

# %%
# get model parameters
asia_model.get_cpds()
# Out:
# [<TabularCPD representing P(asia:2) at 0x2bcc8d5b2b0>,
#  <TabularCPD representing P(bronc:2 | smoke:2) at 0x2bcc8d7cfd0>,
#  <TabularCPD representing P(dysp:2 | bronc:2, either:2) at 0x2bcc8d6ee48>,
#  <TabularCPD representing P(either:2 | lung:2, tub:2) at 0x2bcc8d86da0>,
#  <TabularCPD representing P(lung:2 | smoke:2) at 0x2bcc8d86e80>,
#  <TabularCPD representing P(smoke:2) at 0x2bcc8d86eb8>,
#  <TabularCPD representing P(tub:2 | asia:2) at 0x2bcc8d86c18>,
#  <TabularCPD representing P(xray:2 | either:2) at 0x2bcc8d86d68>]

# %%
# print the CPDs by iterating through them
for cpd in asia_model.get_cpds():
    print("CPD of {variable}:".format(variable=cpd.variable))
    print(cpd)
# Out:
# CPD of asia:
# ╒════════╤══════╕
# │ asia_0 │ 0.01 │
# ├────────┼──────┤
# │ asia_1 │ 0.99 │
# ╘════════╧══════╛
# CPD of bronc:
# ╒═════════╤═════════╤═════════╕
# │ smoke   │ smoke_0 │ smoke_1 │
# ├─────────┼─────────┼─────────┤
# │ bronc_0 │ 0.6     │ 0.3     │
# ├─────────┼─────────┼─────────┤
# │ bronc_1 │ 0.4     │ 0.7     │
# ╘═════════╧═════════╧═════════╛
# CPD of dysp:
# ╒════════╤══════════╤══════════╤══════════╤══════════╕
# │ bronc  │ bronc_0  │ bronc_0  │ bronc_1  │ bronc_1  │
# ├────────┼──────────┼──────────┼──────────┼──────────┤
# │ either │ either_0 │ either_1 │ either_0 │ either_1 │
# ├────────┼──────────┼──────────┼──────────┼──────────┤
# │ dysp_0 │ 0.9      │ 0.7      │ 0.8      │ 0.1      │
# ├────────┼──────────┼──────────┼──────────┼──────────┤
# │ dysp_1 │ 0.1      │ 0.3      │ 0.2      │ 0.9      │
# ╘════════╧══════════╧══════════╧══════════╧══════════╛
# CPD of either:
# ╒══════════╤════════╤════════╤════════╤════════╕
# │ lung     │ lung_0 │ lung_0 │ lung_1 │ lung_1 │
# ├──────────┼────────┼────────┼────────┼────────┤
# │ tub      │ tub_0  │ tub_1  │ tub_0  │ tub_1  │
# ├──────────┼────────┼────────┼────────┼────────┤
# │ either_0 │ 1.0    │ 1.0    │ 1.0    │ 0.0    │
# ├──────────┼────────┼────────┼────────┼────────┤
# │ either_1 │ 0.0    │ 0.0    │ 0.0    │ 1.0    │
# ╘══════════╧════════╧════════╧════════╧════════╛
# CPD of lung:
# ╒════════╤═════════╤═════════╕
# │ smoke  │ smoke_0 │ smoke_1 │
# ├────────┼─────────┼─────────┤
# │ lung_0 │ 0.1     │ 0.01    │
# ├────────┼─────────┼─────────┤
# │ lung_1 │ 0.9     │ 0.99    │
# ╘════════╧═════════╧═════════╛
# CPD of smoke:
# ╒═════════╤═════╕
# │ smoke_0 │ 0.5 │
# ├─────────┼─────┤
# │ smoke_1 │ 0.5 │
# ╘═════════╧═════╛
# CPD of tub:
# ╒═══════╤════════╤════════╕
# │ asia  │ asia_0 │ asia_1 │
# ├───────┼────────┼────────┤
# │ tub_0 │ 0.05   │ 0.01   │
# ├───────┼────────┼────────┤
# │ tub_1 │ 0.95   │ 0.99   │
# ╘═══════╧════════╧════════╛
# CPD of xray:
# ╒════════╤══════════╤══════════╕
# │ either │ either_0 │ either_1 │
# ├────────┼──────────┼──────────┤
# │ xray_0 │ 0.98     │ 0.05     │
# ├────────┼──────────┼──────────┤
# │ xray_1 │ 0.02     │ 0.95     │
# ╘════════╧══════════╧══════════╛

# %%
# get independencies
asia_model.get_independencies()
# Out:
# (asia _|_ smoke, bronc, lung)
# (asia _|_ xray | either)
# (asia _|_ bronc, lung | smoke)
# (asia _|_ smoke, lung | bronc)
# (asia _|_ smoke, bronc | lung)
# (asia _|_ either, smoke, xray, dysp, bronc, lung | tub)
# (asia _|_ xray, dysp, bronc | either, smoke)
# (asia _|_ xray, dysp | either, bronc)
# (asia _|_ xray | either, dysp)
# (asia _|_ smoke, xray, dysp, bronc | either, lung)
# (asia _|_ smoke, xray, dysp, bronc, lung | either, tub)
# (asia _|_ lung | smoke, bronc)
# (asia _|_ bronc | smoke, xray)
# (asia _|_ bronc | smoke, lung)
# (asia _|_ either, xray, dysp, bronc, lung | smoke, tub)
# (asia _|_ smoke | bronc, lung)
# (asia _|_ either, smoke, xray, dysp, lung | tub, bronc)
# (asia _|_ smoke, bronc | xray, lung)
# (asia _|_ either, smoke, dysp, bronc, lung | xray, tub)
# (asia _|_ either, smoke, xray, bronc, lung | dysp, tub)
# (asia _|_ either, smoke, xray, dysp, bronc | tub, lung)
# (asia _|_ xray, dysp | either, smoke, bronc)
# (asia _|_ dysp, bronc | either, smoke, xray)
# (asia _|_ xray, bronc | either, smoke, dysp)
# (asia _|_ xray, dysp, bronc | either, smoke, lung)
# (asia _|_ xray, dysp, bronc, lung | either, smoke, tub)
# (asia _|_ dysp | either, xray, bronc)
# (asia _|_ xray | either, dysp, bronc)
# (asia _|_ smoke, xray, dysp | either, bronc, lung)
# (asia _|_ smoke, xray, dysp, lung | either, tub, bronc)
# (asia _|_ smoke, dysp, bronc | either, xray, lung)
# (asia _|_ smoke, dysp, bronc, lung | either, xray, tub)
# (asia _|_ smoke, xray, bronc | either, dysp, lung)
# (asia _|_ smoke, xray, bronc, lung | either, dysp, tub)
# (asia _|_ smoke, xray, dysp, bronc | either, tub, lung)
# (asia _|_ either, xray, dysp, lung | smoke, tub, bronc)
# (asia _|_ bronc | smoke, xray, lung)
# (asia _|_ either, dysp, bronc, lung | smoke, xray, tub)
# (asia _|_ either, xray, bronc, lung | smoke, dysp, tub)
# (asia _|_ either, xray, dysp, bronc | smoke, tub, lung)
# (asia _|_ smoke | xray, bronc, lung)
# (asia _|_ either, smoke, dysp, lung | xray, tub, bronc)
# (asia _|_ smoke | dysp, bronc, lung)
# (asia _|_ either, smoke, xray, lung | dysp, tub, bronc)
# (asia _|_ either, smoke, xray, dysp | tub, bronc, lung)
# (asia _|_ either, smoke, bronc, lung | xray, dysp, tub)
# (asia _|_ either, smoke, dysp, bronc | xray, tub, lung)
# (asia _|_ either, smoke, xray, bronc | dysp, tub, lung)
# (asia _|_ dysp | either, smoke, xray, bronc)
# (asia _|_ xray | either, smoke, dysp, bronc)
# (asia _|_ xray, dysp | either, smoke, bronc, lung)
# (asia _|_ xray, dysp, lung | either, smoke, tub, bronc)
# (asia _|_ bronc | either, smoke, xray, dysp)
# (asia _|_ dysp, bronc | either, smoke, xray, lung)
# (asia _|_ dysp, bronc, lung | either, smoke, xray, tub)
# (asia _|_ xray, bronc | either, smoke, dysp, lung)
# (asia _|_ xray, bronc, lung | either, smoke, dysp, tub)
# (asia _|_ xray, dysp, bronc | either, smoke, tub, lung)
# (asia _|_ smoke, dysp | either, xray, bronc, lung)
# (asia _|_ smoke, dysp, lung | either, xray, tub, bronc)
# (asia _|_ smoke, xray | either, dysp, bronc, lung)
# (asia _|_ smoke, xray, lung | either, dysp, tub, bronc)
# (asia _|_ smoke, xray, dysp | either, tub, bronc, lung)
# (asia _|_ smoke, bronc | either, xray, dysp, lung)
# (asia _|_ smoke, bronc, lung | either, xray, dysp, tub)
# (asia _|_ smoke, dysp, bronc | either, xray, tub, lung)
# (asia _|_ smoke, xray, bronc | either, dysp, tub, lung)
# (asia _|_ either, dysp, lung | smoke, xray, tub, bronc)
# (asia _|_ either, xray, lung | smoke, dysp, tub, bronc)
# (asia _|_ either, xray, dysp | smoke, tub, bronc, lung)
# (asia _|_ either, bronc, lung | smoke, xray, dysp, tub)
# (asia _|_ either, dysp, bronc | smoke, xray, tub, lung)
# (asia _|_ either, xray, bronc | smoke, dysp, tub, lung)
# (asia _|_ smoke | xray, dysp, bronc, lung)
# (asia _|_ either, smoke, lung | xray, dysp, tub, bronc)
# (asia _|_ either, smoke, dysp | xray, tub, bronc, lung)
# (asia _|_ either, smoke, xray | dysp, tub, bronc, lung)
# (asia _|_ either, smoke, bronc | xray, dysp, tub, lung)
# (asia _|_ dysp | either, smoke, bronc, xray, lung)
# (asia _|_ dysp, lung | either, smoke, bronc, xray, tub)
# (asia _|_ xray | either, smoke, bronc, dysp, lung)
# (asia _|_ xray, lung | either, smoke, bronc, dysp, tub)
# (asia _|_ xray, dysp | either, smoke, bronc, lung, tub)
# (asia _|_ bronc | either, smoke, xray, dysp, lung)
# (asia _|_ bronc, lung | either, smoke, xray, dysp, tub)
# (asia _|_ dysp, bronc | either, smoke, xray, lung, tub)
# (asia _|_ xray, bronc | either, smoke, dysp, lung, tub)
# (asia _|_ smoke | either, bronc, xray, dysp, lung)
# (asia _|_ smoke, lung | either, bronc, xray, dysp, tub)
# (asia _|_ smoke, dysp | either, bronc, xray, lung, tub)
# (asia _|_ smoke, xray | either, bronc, dysp, lung, tub)
# (asia _|_ smoke, bronc | either, xray, dysp, lung, tub)
# (asia _|_ either, lung | smoke, bronc, xray, dysp, tub)
# (asia _|_ either, dysp | smoke, bronc, xray, lung, tub)
# (asia _|_ either, xray | smoke, bronc, dysp, lung, tub)
# (asia _|_ either, bronc | smoke, xray, dysp, lung, tub)
# (asia _|_ either, smoke | bronc, xray, dysp, lung, tub)
# (asia _|_ lung | either, smoke, bronc, xray, dysp, tub)
# (asia _|_ dysp | either, smoke, bronc, xray, lung, tub)
# (asia _|_ xray | either, smoke, bronc, dysp, lung, tub)
# (asia _|_ bronc | either, smoke, xray, dysp, lung, tub)
# (asia _|_ smoke | either, bronc, xray, dysp, lung, tub)
# (asia _|_ either | smoke, bronc, xray, dysp, lung, tub)
# (tub _|_ smoke, bronc, lung)
# (tub _|_ smoke, bronc, lung | asia)
# (tub _|_ xray | either)
# (tub _|_ bronc, lung | smoke)
# (tub _|_ smoke, lung | bronc)
# (tub _|_ smoke, bronc | lung)
# (tub _|_ xray | asia, either)
# (tub _|_ bronc, lung | asia, smoke)
# (tub _|_ smoke, lung | asia, bronc)
# (tub _|_ smoke, bronc | asia, lung)
# (tub _|_ xray, dysp, bronc | either, smoke)
# (tub _|_ xray, dysp | either, bronc)
# (tub _|_ xray | either, dysp)
# (tub _|_ smoke, xray, dysp, bronc | either, lung)
# (tub _|_ lung | smoke, bronc)
# (tub _|_ bronc | smoke, xray)
# (tub _|_ bronc | smoke, lung)
# (tub _|_ smoke | bronc, lung)
# (tub _|_ smoke, bronc | xray, lung)
# (tub _|_ xray, dysp, bronc | asia, smoke, either)
# (tub _|_ xray, dysp | asia, either, bronc)
# (tub _|_ xray | asia, dysp, either)
# (tub _|_ smoke, xray, dysp, bronc | asia, either, lung)
# (tub _|_ lung | asia, smoke, bronc)
# (tub _|_ bronc | asia, smoke, xray)
# (tub _|_ bronc | asia, smoke, lung)
# (tub _|_ smoke | asia, bronc, lung)
# (tub _|_ smoke, bronc | asia, xray, lung)
# (tub _|_ xray, dysp | either, smoke, bronc)
# (tub _|_ dysp, bronc | either, smoke, xray)
# (tub _|_ xray, bronc | either, smoke, dysp)
# (tub _|_ xray, dysp, bronc | either, smoke, lung)
# (tub _|_ dysp | either, xray, bronc)
# (tub _|_ xray | either, dysp, bronc)
# (tub _|_ smoke, xray, dysp | either, bronc, lung)
# (tub _|_ smoke, dysp, bronc | either, xray, lung)
# (tub _|_ smoke, xray, bronc | either, dysp, lung)
# (tub _|_ bronc | smoke, xray, lung)
# (tub _|_ smoke | xray, bronc, lung)
# (tub _|_ smoke | dysp, bronc, lung)
# (tub _|_ xray, dysp | asia, smoke, either, bronc)
# (tub _|_ dysp, bronc | asia, smoke, xray, either)
# (tub _|_ xray, bronc | asia, smoke, dysp, either)
# (tub _|_ xray, dysp, bronc | asia, smoke, either, lung)
# (tub _|_ dysp | asia, xray, either, bronc)
# (tub _|_ xray | asia, dysp, either, bronc)
# (tub _|_ smoke, xray, dysp | asia, either, bronc, lung)
# (tub _|_ smoke, dysp, bronc | asia, xray, either, lung)
# (tub _|_ smoke, xray, bronc | asia, dysp, either, lung)
# (tub _|_ bronc | asia, smoke, xray, lung)
# (tub _|_ smoke | asia, xray, bronc, lung)
# (tub _|_ smoke | asia, dysp, bronc, lung)
# (tub _|_ dysp | either, smoke, xray, bronc)
# (tub _|_ xray | either, smoke, dysp, bronc)
# (tub _|_ xray, dysp | either, smoke, bronc, lung)
# (tub _|_ bronc | either, smoke, xray, dysp)
# (tub _|_ dysp, bronc | either, smoke, xray, lung)
# (tub _|_ xray, bronc | either, smoke, dysp, lung)
# (tub _|_ smoke, dysp | either, xray, bronc, lung)
# (tub _|_ smoke, xray | either, dysp, bronc, lung)
# (tub _|_ smoke, bronc | either, xray, dysp, lung)
# (tub _|_ smoke | xray, dysp, bronc, lung)
# (tub _|_ dysp | asia, either, smoke, bronc, xray)
# (tub _|_ xray | asia, either, smoke, bronc, dysp)
# (tub _|_ xray, dysp | asia, either, smoke, bronc, lung)
# (tub _|_ bronc | asia, either, smoke, xray, dysp)
# (tub _|_ dysp, bronc | asia, either, smoke, xray, lung)
# (tub _|_ xray, bronc | asia, either, smoke, dysp, lung)
# (tub _|_ smoke, dysp | asia, either, bronc, xray, lung)
# (tub _|_ smoke, xray | asia, either, bronc, dysp, lung)
# (tub _|_ smoke, bronc | asia, either, xray, dysp, lung)
# (tub _|_ smoke | asia, bronc, xray, dysp, lung)
# (tub _|_ dysp | either, smoke, bronc, xray, lung)
# (tub _|_ xray | either, smoke, bronc, dysp, lung)
# (tub _|_ bronc | either, smoke, xray, dysp, lung)
# (tub _|_ smoke | either, bronc, xray, dysp, lung)
# (tub _|_ dysp | asia, either, smoke, bronc, xray, lung)
# (tub _|_ xray | asia, either, smoke, bronc, dysp, lung)
# (tub _|_ bronc | asia, either, smoke, xray, dysp, lung)
# (tub _|_ smoke | asia, either, bronc, xray, dysp, lung)
# (smoke _|_ asia, tub)
# (smoke _|_ tub | asia)
# (smoke _|_ xray | either)
# (smoke _|_ asia, tub | bronc)
# (smoke _|_ asia, xray, tub, either | lung)
# (smoke _|_ asia | tub)
# (smoke _|_ xray | asia, either)
# (smoke _|_ tub | asia, bronc)
# (smoke _|_ either, xray, tub | asia, lung)
# (smoke _|_ xray, dysp | either, bronc)
# (smoke _|_ xray | either, dysp)
# (smoke _|_ asia, xray, tub | either, lung)
# (smoke _|_ asia, xray | either, tub)
# (smoke _|_ asia, either, xray, dysp, tub | bronc, lung)
# (smoke _|_ asia | tub, bronc)
# (smoke _|_ asia, tub, either | xray, lung)
# (smoke _|_ asia | xray, tub)
# (smoke _|_ asia | dysp, tub)
# (smoke _|_ asia, xray, either | tub, lung)
# (smoke _|_ xray, dysp | asia, either, bronc)
# (smoke _|_ xray | asia, dysp, either)
# (smoke _|_ xray, tub | asia, either, lung)
# (smoke _|_ xray | asia, tub, either)
# (smoke _|_ either, xray, dysp, tub | asia, bronc, lung)
# (smoke _|_ either, tub | asia, xray, lung)
# (smoke _|_ either, xray | asia, tub, lung)
# (smoke _|_ dysp | either, xray, bronc)
# (smoke _|_ xray | either, dysp, bronc)
# (smoke _|_ asia, xray, dysp, tub | either, bronc, lung)
# (smoke _|_ asia, xray, dysp | either, tub, bronc)
# (smoke _|_ asia, tub | either, xray, lung)
# (smoke _|_ asia | either, xray, tub)
# (smoke _|_ asia, xray, tub | either, dysp, lung)
# (smoke _|_ asia, xray | either, dysp, tub)
# (smoke _|_ asia, xray | either, tub, lung)
# (smoke _|_ asia, dysp, tub, either | xray, bronc, lung)
# (smoke _|_ asia | xray, tub, bronc)
# (smoke _|_ asia, xray, tub, either | dysp, bronc, lung)
# (smoke _|_ asia | dysp, tub, bronc)
# (smoke _|_ asia, xray, dysp, either | tub, bronc, lung)
# (smoke _|_ asia | xray, dysp, tub)
# (smoke _|_ asia, either | xray, tub, lung)
# (smoke _|_ asia | dysp, tub, lung)
# (smoke _|_ dysp | asia, xray, either, bronc)
# (smoke _|_ xray | asia, dysp, either, bronc)
# (smoke _|_ xray, dysp, tub | asia, either, bronc, lung)
# (smoke _|_ xray, dysp | asia, tub, either, bronc)
# (smoke _|_ tub | asia, xray, either, lung)
# (smoke _|_ xray, tub | asia, dysp, either, lung)
# (smoke _|_ xray | asia, dysp, tub, either)
# (smoke _|_ xray | asia, tub, either, lung)
# (smoke _|_ either, dysp, tub | asia, xray, bronc, lung)
# (smoke _|_ either, xray, tub | asia, dysp, bronc, lung)
# (smoke _|_ either, xray, dysp | asia, tub, bronc, lung)
# (smoke _|_ either | asia, xray, tub, lung)
# (smoke _|_ asia, dysp, tub | either, xray, bronc, lung)
# (smoke _|_ asia, dysp | either, xray, tub, bronc)
# (smoke _|_ asia, xray, tub | either, dysp, bronc, lung)
# (smoke _|_ asia, xray | either, dysp, tub, bronc)
# (smoke _|_ asia, xray, dysp | either, tub, bronc, lung)
# (smoke _|_ asia, tub | either, xray, dysp, lung)
# (smoke _|_ asia | either, xray, dysp, tub)
# (smoke _|_ asia | either, xray, tub, lung)
# (smoke _|_ asia, xray | either, dysp, tub, lung)
# (smoke _|_ asia, tub, either | xray, dysp, bronc, lung)
# (smoke _|_ asia | xray, dysp, tub, bronc)
# (smoke _|_ asia, dysp, either | xray, tub, bronc, lung)
# (smoke _|_ asia, xray, either | dysp, tub, bronc, lung)
# (smoke _|_ asia | xray, dysp, tub, lung)
# (smoke _|_ dysp, tub | asia, either, bronc, xray, lung)
# (smoke _|_ dysp | asia, either, bronc, xray, tub)
# (smoke _|_ xray, tub | asia, either, bronc, dysp, lung)
# (smoke _|_ xray | asia, either, bronc, dysp, tub)
# (smoke _|_ xray, dysp | asia, either, bronc, lung, tub)
# (smoke _|_ tub | asia, either, xray, dysp, lung)
# (smoke _|_ xray | asia, either, dysp, lung, tub)
# (smoke _|_ either, tub | asia, bronc, xray, dysp, lung)
# (smoke _|_ either, dysp | asia, bronc, xray, lung, tub)
# (smoke _|_ either, xray | asia, bronc, dysp, lung, tub)
# (smoke _|_ asia, tub | either, bronc, xray, dysp, lung)
# (smoke _|_ asia | either, bronc, xray, dysp, tub)
# (smoke _|_ asia, dysp | either, bronc, xray, lung, tub)
# (smoke _|_ asia, xray | either, bronc, dysp, lung, tub)
# (smoke _|_ asia | either, xray, dysp, lung, tub)
# (smoke _|_ asia, either | bronc, xray, dysp, lung, tub)
# (smoke _|_ tub | asia, either, bronc, xray, dysp, lung)
# (smoke _|_ dysp | asia, either, bronc, xray, lung, tub)
# (smoke _|_ xray | asia, either, bronc, dysp, lung, tub)
# (smoke _|_ either | asia, bronc, xray, dysp, lung, tub)
# (smoke _|_ asia | either, bronc, xray, dysp, lung, tub)
# (lung _|_ asia, tub)
# (lung _|_ tub | asia)
# (lung _|_ xray | either)
# (lung _|_ asia, tub, bronc | smoke)
# (lung _|_ asia, tub | bronc)
# (lung _|_ asia | tub)
# (lung _|_ xray | asia, either)
# (lung _|_ tub, bronc | asia, smoke)
# (lung _|_ tub | asia, bronc)
# (lung _|_ xray, dysp, bronc | either, smoke)
# (lung _|_ xray, dysp | either, bronc)
# (lung _|_ xray | either, dysp)
# (lung _|_ asia, xray | either, tub)
# (lung _|_ asia, tub | smoke, bronc)
# (lung _|_ bronc | smoke, xray)
# (lung _|_ asia, bronc | smoke, tub)
# (lung _|_ asia | tub, bronc)
# (lung _|_ asia | xray, tub)
# (lung _|_ asia | dysp, tub)
# (lung _|_ xray, dysp, bronc | asia, smoke, either)
# (lung _|_ xray, dysp | asia, either, bronc)
# (lung _|_ xray | asia, dysp, either)
# (lung _|_ xray | asia, tub, either)
# (lung _|_ tub | asia, smoke, bronc)
# (lung _|_ bronc | asia, smoke, xray)
# (lung _|_ bronc | asia, smoke, tub)
# (lung _|_ xray, dysp | either, smoke, bronc)
# (lung _|_ dysp, bronc | either, smoke, xray)
# (lung _|_ xray, bronc | either, smoke, dysp)
# (lung _|_ asia, xray, dysp, bronc | either, smoke, tub)
# (lung _|_ dysp | either, xray, bronc)
# (lung _|_ xray | either, dysp, bronc)
# (lung _|_ asia, xray, dysp | either, tub, bronc)
# (lung _|_ asia | either, xray, tub)
# (lung _|_ asia, xray | either, dysp, tub)
# (lung _|_ asia | smoke, tub, bronc)
# (lung _|_ asia, bronc | smoke, xray, tub)
# (lung _|_ asia | smoke, dysp, tub)
# (lung _|_ asia | xray, tub, bronc)
# (lung _|_ asia | dysp, tub, bronc)
# (lung _|_ asia | xray, dysp, tub)
# (lung _|_ xray, dysp | asia, smoke, either, bronc)
# (lung _|_ dysp, bronc | asia, smoke, xray, either)
# (lung _|_ xray, bronc | asia, smoke, dysp, either)
# (lung _|_ xray, dysp, bronc | asia, smoke, tub, either)
# (lung _|_ dysp | asia, xray, either, bronc)
# (lung _|_ xray | asia, dysp, either, bronc)
# (lung _|_ xray, dysp | asia, tub, either, bronc)
# (lung _|_ xray | asia, dysp, tub, either)
# (lung _|_ bronc | asia, smoke, xray, tub)
# (lung _|_ dysp | either, smoke, xray, bronc)
# (lung _|_ xray | either, smoke, dysp, bronc)
# (lung _|_ asia, xray, dysp | either, smoke, tub, bronc)
# (lung _|_ bronc | either, smoke, xray, dysp)
# (lung _|_ asia, dysp, bronc | either, smoke, xray, tub)
# (lung _|_ asia, xray, bronc | either, smoke, dysp, tub)
# (lung _|_ asia, dysp | either, xray, tub, bronc)
# (lung _|_ asia, xray | either, dysp, tub, bronc)
# (lung _|_ asia | either, xray, dysp, tub)
# (lung _|_ asia | smoke, xray, tub, bronc)
# (lung _|_ asia | smoke, dysp, tub, bronc)
# (lung _|_ asia | smoke, xray, dysp, tub)
# (lung _|_ asia | xray, dysp, tub, bronc)
# (lung _|_ dysp | asia, either, smoke, bronc, xray)
# (lung _|_ xray | asia, either, smoke, bronc, dysp)
# (lung _|_ xray, dysp | asia, either, smoke, bronc, tub)
# (lung _|_ bronc | asia, either, smoke, xray, dysp)
# (lung _|_ dysp, bronc | asia, either, smoke, xray, tub)
# (lung _|_ xray, bronc | asia, either, smoke, dysp, tub)
# (lung _|_ dysp | asia, either, bronc, xray, tub)
# (lung _|_ xray | asia, either, bronc, dysp, tub)
# (lung _|_ asia, dysp | either, smoke, bronc, xray, tub)
# (lung _|_ asia, xray | either, smoke, bronc, dysp, tub)
# (lung _|_ asia, bronc | either, smoke, xray, dysp, tub)
# (lung _|_ asia | either, bronc, xray, dysp, tub)
# (lung _|_ asia | smoke, bronc, xray, dysp, tub)
# (lung _|_ dysp | asia, either, smoke, bronc, xray, tub)
# (lung _|_ xray | asia, either, smoke, bronc, dysp, tub)
# (lung _|_ bronc | asia, either, smoke, xray, dysp, tub)
# (lung _|_ asia | either, smoke, bronc, xray, dysp, tub)
# (bronc _|_ asia, tub)
# (bronc _|_ tub | asia)
# (bronc _|_ xray | either)
# (bronc _|_ asia, either, xray, lung, tub | smoke)
# (bronc _|_ asia, xray, tub, either | lung)
# (bronc _|_ asia | tub)
# (bronc _|_ xray | asia, either)
# (bronc _|_ either, xray, tub, lung | asia, smoke)
# (bronc _|_ either, xray, tub | asia, lung)
# (bronc _|_ asia, xray, tub, lung | either, smoke)
# (bronc _|_ xray | either, dysp)
# (bronc _|_ asia, xray, tub | either, lung)
# (bronc _|_ asia, xray | either, tub)
# (bronc _|_ asia, tub, either, lung | smoke, xray)
# (bronc _|_ asia, xray, tub, either | smoke, lung)
# (bronc _|_ asia, xray, either, lung | smoke, tub)
# (bronc _|_ asia, tub, either | xray, lung)
# (bronc _|_ asia | xray, tub)
# (bronc _|_ asia | dysp, tub)
# (bronc _|_ asia, xray, either | tub, lung)
# (bronc _|_ xray, tub, lung | asia, smoke, either)
# (bronc _|_ xray | asia, dysp, either)
# (bronc _|_ xray, tub | asia, either, lung)
# (bronc _|_ xray | asia, tub, either)
# (bronc _|_ either, tub, lung | asia, smoke, xray)
# (bronc _|_ either, xray, tub | asia, smoke, lung)
# (bronc _|_ either, xray, lung | asia, smoke, tub)
# (bronc _|_ either, tub | asia, xray, lung)
# (bronc _|_ either, xray | asia, tub, lung)
# (bronc _|_ asia, tub, lung | either, smoke, xray)
# (bronc _|_ asia, xray, tub, lung | either, smoke, dysp)
# (bronc _|_ asia, xray, tub | either, smoke, lung)
# (bronc _|_ asia, xray, lung | either, smoke, tub)
# (bronc _|_ asia, tub | either, xray, lung)
# (bronc _|_ asia | either, xray, tub)
# (bronc _|_ asia, xray, tub | either, dysp, lung)
# (bronc _|_ asia, xray | either, dysp, tub)
# (bronc _|_ asia, xray | either, tub, lung)
# (bronc _|_ asia, tub, either | smoke, xray, lung)
# (bronc _|_ asia, either, lung | smoke, xray, tub)
# (bronc _|_ asia | smoke, dysp, tub)
# (bronc _|_ asia, xray, either | smoke, tub, lung)
# (bronc _|_ asia | xray, dysp, tub)
# (bronc _|_ asia, either | xray, tub, lung)
# (bronc _|_ asia | dysp, tub, lung)
# (bronc _|_ tub, lung | asia, smoke, xray, either)
# (bronc _|_ xray, tub, lung | asia, smoke, dysp, either)
# (bronc _|_ xray, tub | asia, smoke, either, lung)
# (bronc _|_ xray, lung | asia, smoke, tub, either)
# (bronc _|_ tub | asia, xray, either, lung)
# (bronc _|_ xray, tub | asia, dysp, either, lung)
# (bronc _|_ xray | asia, dysp, tub, either)
# (bronc _|_ xray | asia, tub, either, lung)
# (bronc _|_ either, tub | asia, smoke, xray, lung)
# (bronc _|_ either, lung | asia, smoke, xray, tub)
# (bronc _|_ either, xray | asia, smoke, tub, lung)
# (bronc _|_ either | asia, xray, tub, lung)
# (bronc _|_ asia, tub, lung | either, smoke, xray, dysp)
# (bronc _|_ asia, tub | either, smoke, xray, lung)
# (bronc _|_ asia, lung | either, smoke, xray, tub)
# (bronc _|_ asia, xray, tub | either, smoke, dysp, lung)
# (bronc _|_ asia, xray, lung | either, smoke, dysp, tub)
# (bronc _|_ asia, xray | either, smoke, tub, lung)
# (bronc _|_ asia, tub | either, xray, dysp, lung)
# (bronc _|_ asia | either, xray, dysp, tub)
# (bronc _|_ asia | either, xray, tub, lung)
# (bronc _|_ asia, xray | either, dysp, tub, lung)
# (bronc _|_ asia | smoke, xray, dysp, tub)
# (bronc _|_ asia, either | smoke, xray, tub, lung)
# (bronc _|_ asia | smoke, dysp, tub, lung)
# (bronc _|_ asia | xray, dysp, tub, lung)
# (bronc _|_ tub, lung | asia, either, smoke, xray, dysp)
# (bronc _|_ tub | asia, either, smoke, xray, lung)
# (bronc _|_ lung | asia, either, smoke, xray, tub)
# (bronc _|_ xray, tub | asia, either, smoke, dysp, lung)
# (bronc _|_ xray, lung | asia, either, smoke, dysp, tub)
# (bronc _|_ xray | asia, either, smoke, lung, tub)
# (bronc _|_ tub | asia, either, xray, dysp, lung)
# (bronc _|_ xray | asia, either, dysp, lung, tub)
# (bronc _|_ either | asia, smoke, xray, lung, tub)
# (bronc _|_ asia, tub | either, smoke, xray, dysp, lung)
# (bronc _|_ asia, lung | either, smoke, xray, dysp, tub)
# (bronc _|_ asia | either, smoke, xray, lung, tub)
# (bronc _|_ asia, xray | either, smoke, dysp, lung, tub)
# (bronc _|_ asia | either, xray, dysp, lung, tub)
# (bronc _|_ asia | smoke, xray, dysp, lung, tub)
# (bronc _|_ tub | asia, either, smoke, xray, dysp, lung)
# (bronc _|_ lung | asia, either, smoke, xray, dysp, tub)
# (bronc _|_ xray | asia, either, smoke, dysp, lung, tub)
# (bronc _|_ asia | either, smoke, xray, dysp, lung, tub)
# (either _|_ bronc | smoke)
# (either _|_ smoke, bronc | lung)
# (either _|_ asia | tub)
# (either _|_ bronc | asia, smoke)
# (either _|_ smoke, bronc | asia, lung)
# (either _|_ bronc | smoke, xray)
# (either _|_ bronc | smoke, lung)
# (either _|_ asia, bronc | smoke, tub)
# (either _|_ smoke | bronc, lung)
# (either _|_ asia | tub, bronc)
# (either _|_ smoke, bronc | xray, lung)
# (either _|_ asia | xray, tub)
# (either _|_ asia | dysp, tub)
# (either _|_ asia, smoke, bronc | tub, lung)
# (either _|_ bronc | asia, smoke, xray)
# (either _|_ bronc | asia, smoke, lung)
# (either _|_ bronc | asia, smoke, tub)
# (either _|_ smoke | asia, bronc, lung)
# (either _|_ smoke, bronc | asia, xray, lung)
# (either _|_ smoke, bronc | asia, tub, lung)
# (either _|_ asia | smoke, tub, bronc)
# (either _|_ bronc | smoke, xray, lung)
# (either _|_ asia, bronc | smoke, xray, tub)
# (either _|_ asia | smoke, dysp, tub)
# (either _|_ asia, bronc | smoke, tub, lung)
# (either _|_ smoke | xray, bronc, lung)
# (either _|_ asia | xray, tub, bronc)
# (either _|_ smoke | dysp, bronc, lung)
# (either _|_ asia | dysp, tub, bronc)
# (either _|_ asia, smoke | tub, bronc, lung)
# (either _|_ asia | xray, dysp, tub)
# (either _|_ asia, smoke, bronc | xray, tub, lung)
# (either _|_ asia | dysp, tub, lung)
# (either _|_ bronc | asia, smoke, xray, lung)
# (either _|_ bronc | asia, smoke, xray, tub)
# (either _|_ bronc | asia, smoke, tub, lung)
# (either _|_ smoke | asia, xray, bronc, lung)
# (either _|_ smoke | asia, dysp, bronc, lung)
# (either _|_ smoke | asia, tub, bronc, lung)
# (either _|_ smoke, bronc | asia, xray, tub, lung)
# (either _|_ asia | smoke, xray, tub, bronc)
# (either _|_ asia | smoke, dysp, tub, bronc)
# (either _|_ asia | smoke, tub, bronc, lung)
# (either _|_ asia | smoke, xray, dysp, tub)
# (either _|_ asia, bronc | smoke, xray, tub, lung)
# (either _|_ asia | smoke, dysp, tub, lung)
# (either _|_ smoke | xray, dysp, bronc, lung)
# (either _|_ asia | xray, dysp, tub, bronc)
# (either _|_ asia, smoke | xray, tub, bronc, lung)
# (either _|_ asia, smoke | dysp, tub, bronc, lung)
# (either _|_ asia | xray, dysp, tub, lung)
# (either _|_ bronc | asia, smoke, xray, lung, tub)
# (either _|_ smoke | asia, bronc, xray, dysp, lung)
# (either _|_ smoke | asia, bronc, xray, lung, tub)
# (either _|_ smoke | asia, bronc, dysp, lung, tub)
# (either _|_ asia | smoke, bronc, xray, dysp, tub)
# (either _|_ asia | smoke, bronc, xray, lung, tub)
# (either _|_ asia | smoke, bronc, dysp, lung, tub)
# (either _|_ asia | smoke, xray, dysp, lung, tub)
# (either _|_ asia, smoke | bronc, xray, dysp, lung, tub)
# (either _|_ smoke | asia, bronc, xray, dysp, lung, tub)
# (either _|_ asia | smoke, bronc, xray, dysp, lung, tub)
# (xray _|_ asia, smoke, dysp, bronc, lung, tub | either)
# (xray _|_ bronc | smoke)
# (xray _|_ smoke, bronc | lung)
# (xray _|_ asia | tub)
# (xray _|_ smoke, dysp, bronc, lung, tub | asia, either)
# (xray _|_ bronc | asia, smoke)
# (xray _|_ smoke, bronc | asia, lung)
# (xray _|_ asia, dysp, bronc, lung, tub | either, smoke)
# (xray _|_ asia, smoke, dysp, lung, tub | either, bronc)
# (xray _|_ asia, smoke, bronc, lung, tub | either, dysp)
# (xray _|_ asia, smoke, dysp, bronc, tub | either, lung)
# (xray _|_ asia, smoke, dysp, bronc, lung | either, tub)
# (xray _|_ bronc | smoke, lung)
# (xray _|_ asia, bronc | smoke, tub)
# (xray _|_ smoke | bronc, lung)
# (xray _|_ asia | tub, bronc)
# (xray _|_ asia | dysp, tub)
# (xray _|_ asia, smoke, bronc | tub, lung)
# (xray _|_ dysp, tub, bronc, lung | asia, smoke, either)
# (xray _|_ smoke, dysp, tub, lung | asia, either, bronc)
# (xray _|_ smoke, tub, bronc, lung | asia, dysp, either)
# (xray _|_ smoke, dysp, tub, bronc | asia, either, lung)
# (xray _|_ smoke, dysp, bronc, lung | asia, tub, either)
# (xray _|_ bronc | asia, smoke, lung)
# (xray _|_ bronc | asia, smoke, tub)
# (xray _|_ smoke | asia, bronc, lung)
# (xray _|_ smoke, bronc | asia, tub, lung)
# (xray _|_ asia, dysp, tub, lung | either, smoke, bronc)
# (xray _|_ asia, tub, bronc, lung | either, smoke, dysp)
# (xray _|_ asia, dysp, tub, bronc | either, smoke, lung)
# (xray _|_ asia, dysp, bronc, lung | either, smoke, tub)
# (xray _|_ asia, smoke, tub, lung | either, dysp, bronc)
# (xray _|_ asia, smoke, dysp, tub | either, bronc, lung)
# (xray _|_ asia, smoke, dysp, lung | either, tub, bronc)
# (xray _|_ asia, smoke, tub, bronc | either, dysp, lung)
# (xray _|_ asia, smoke, bronc, lung | either, dysp, tub)
# (xray _|_ asia, smoke, dysp, bronc | either, tub, lung)
# (xray _|_ asia | smoke, tub, bronc)
# (xray _|_ asia | smoke, dysp, tub)
# (xray _|_ asia, bronc | smoke, tub, lung)
# (xray _|_ smoke | dysp, bronc, lung)
# (xray _|_ asia | dysp, tub, bronc)
# (xray _|_ asia, smoke | tub, bronc, lung)
# (xray _|_ asia | dysp, tub, lung)
# (xray _|_ dysp, tub, lung | asia, smoke, either, bronc)
# (xray _|_ tub, bronc, lung | asia, smoke, dysp, either)
# (xray _|_ dysp, tub, bronc | asia, smoke, either, lung)
# (xray _|_ dysp, bronc, lung | asia, smoke, tub, either)
# (xray _|_ smoke, tub, lung | asia, dysp, either, bronc)
# (xray _|_ smoke, dysp, tub | asia, either, bronc, lung)
# (xray _|_ smoke, dysp, lung | asia, tub, either, bronc)
# (xray _|_ smoke, tub, bronc | asia, dysp, either, lung)
# (xray _|_ smoke, bronc, lung | asia, dysp, tub, either)
# (xray _|_ smoke, dysp, bronc | asia, tub, either, lung)
# (xray _|_ bronc | asia, smoke, tub, lung)
# (xray _|_ smoke | asia, dysp, bronc, lung)
# (xray _|_ smoke | asia, tub, bronc, lung)
# (xray _|_ asia, tub, lung | either, smoke, dysp, bronc)
# (xray _|_ asia, dysp, tub | either, smoke, bronc, lung)
# (xray _|_ asia, dysp, lung | either, smoke, tub, bronc)
# (xray _|_ asia, tub, bronc | either, smoke, dysp, lung)
# (xray _|_ asia, bronc, lung | either, smoke, dysp, tub)
# (xray _|_ asia, dysp, bronc | either, smoke, tub, lung)
# (xray _|_ asia, smoke, tub | either, dysp, bronc, lung)
# (xray _|_ asia, smoke, lung | either, dysp, tub, bronc)
# (xray _|_ asia, smoke, dysp | either, tub, bronc, lung)
# (xray _|_ asia, smoke, bronc | either, dysp, tub, lung)
# (xray _|_ asia | smoke, dysp, tub, bronc)
# (xray _|_ asia | smoke, tub, bronc, lung)
# (xray _|_ asia | smoke, dysp, tub, lung)
# (xray _|_ asia, smoke | dysp, tub, bronc, lung)
# (xray _|_ tub, lung | asia, either, smoke, bronc, dysp)
# (xray _|_ dysp, tub | asia, either, smoke, bronc, lung)
# (xray _|_ dysp, lung | asia, either, smoke, bronc, tub)
# (xray _|_ tub, bronc | asia, either, smoke, dysp, lung)
# (xray _|_ bronc, lung | asia, either, smoke, dysp, tub)
# (xray _|_ dysp, bronc | asia, either, smoke, lung, tub)
# (xray _|_ smoke, tub | asia, either, bronc, dysp, lung)
# (xray _|_ smoke, lung | asia, either, bronc, dysp, tub)
# (xray _|_ smoke, dysp | asia, either, bronc, lung, tub)
# (xray _|_ smoke, bronc | asia, either, dysp, lung, tub)
# (xray _|_ smoke | asia, bronc, dysp, lung, tub)
# (xray _|_ asia, tub | either, smoke, bronc, dysp, lung)
# (xray _|_ asia, lung | either, smoke, bronc, dysp, tub)
# (xray _|_ asia, dysp | either, smoke, bronc, lung, tub)
# (xray _|_ asia, bronc | either, smoke, dysp, lung, tub)
# (xray _|_ asia, smoke | either, bronc, dysp, lung, tub)
# (xray _|_ asia | smoke, bronc, dysp, lung, tub)
# (xray _|_ tub | asia, either, smoke, bronc, dysp, lung)
# (xray _|_ lung | asia, either, smoke, bronc, dysp, tub)
# (xray _|_ dysp | asia, either, smoke, bronc, lung, tub)
# (xray _|_ bronc | asia, either, smoke, dysp, lung, tub)
# (xray _|_ smoke | asia, either, bronc, dysp, lung, tub)
# (xray _|_ asia | either, smoke, bronc, dysp, lung, tub)
# (dysp _|_ xray | either)
# (dysp _|_ asia | tub)
# (dysp _|_ xray | asia, either)
# (dysp _|_ asia, xray, tub, lung | either, smoke)
# (dysp _|_ asia, smoke, xray, lung, tub | either, bronc)
# (dysp _|_ asia, xray, tub | either, lung)
# (dysp _|_ asia, xray | either, tub)
# (dysp _|_ asia | smoke, tub)
# (dysp _|_ smoke | bronc, lung)
# (dysp _|_ asia | tub, bronc)
# (dysp _|_ asia | xray, tub)
# (dysp _|_ asia | tub, lung)
# (dysp _|_ xray, tub, lung | asia, smoke, either)
# (dysp _|_ smoke, xray, tub, lung | asia, either, bronc)
# (dysp _|_ xray, tub | asia, either, lung)
# (dysp _|_ xray | asia, tub, either)
# (dysp _|_ smoke | asia, bronc, lung)
# (dysp _|_ asia, xray, tub, lung | either, smoke, bronc)
# (dysp _|_ asia, tub, lung | either, smoke, xray)
# (dysp _|_ asia, xray, tub | either, smoke, lung)
# (dysp _|_ asia, xray, lung | either, smoke, tub)
# (dysp _|_ asia, smoke, tub, lung | either, xray, bronc)
# (dysp _|_ asia, smoke, xray, tub | either, bronc, lung)
# (dysp _|_ asia, smoke, xray, lung | either, tub, bronc)
# (dysp _|_ asia, tub | either, xray, lung)
# (dysp _|_ asia | either, xray, tub)
# (dysp _|_ asia, xray | either, tub, lung)
# (dysp _|_ asia | smoke, tub, bronc)
# (dysp _|_ asia | smoke, xray, tub)
# (dysp _|_ asia | smoke, tub, lung)
# (dysp _|_ smoke | xray, bronc, lung)
# (dysp _|_ asia | xray, tub, bronc)
# (dysp _|_ asia, smoke | tub, bronc, lung)
# (dysp _|_ asia | xray, tub, lung)
# (dysp _|_ xray, tub, lung | asia, smoke, either, bronc)
# (dysp _|_ tub, lung | asia, smoke, xray, either)
# (dysp _|_ xray, tub | asia, smoke, either, lung)
# (dysp _|_ xray, lung | asia, smoke, tub, either)
# (dysp _|_ smoke, tub, lung | asia, xray, either, bronc)
# (dysp _|_ smoke, xray, tub | asia, either, bronc, lung)
# (dysp _|_ smoke, xray, lung | asia, tub, either, bronc)
# (dysp _|_ tub | asia, xray, either, lung)
# (dysp _|_ xray | asia, tub, either, lung)
# (dysp _|_ smoke | asia, xray, bronc, lung)
# (dysp _|_ smoke | asia, tub, bronc, lung)
# (dysp _|_ asia, tub, lung | either, smoke, xray, bronc)
# (dysp _|_ asia, xray, tub | either, smoke, bronc, lung)
# (dysp _|_ asia, xray, lung | either, smoke, tub, bronc)
# (dysp _|_ asia, tub | either, smoke, xray, lung)
# (dysp _|_ asia, lung | either, smoke, xray, tub)
# (dysp _|_ asia, xray | either, smoke, tub, lung)
# (dysp _|_ asia, smoke, tub | either, xray, bronc, lung)
# (dysp _|_ asia, smoke, lung | either, xray, tub, bronc)
# (dysp _|_ asia, smoke, xray | either, tub, bronc, lung)
# (dysp _|_ asia | either, xray, tub, lung)
# (dysp _|_ asia | smoke, xray, tub, bronc)
# (dysp _|_ asia | smoke, tub, bronc, lung)
# (dysp _|_ asia | smoke, xray, tub, lung)
# (dysp _|_ asia, smoke | xray, tub, bronc, lung)
# (dysp _|_ tub, lung | asia, either, smoke, bronc, xray)
# (dysp _|_ xray, tub | asia, either, smoke, bronc, lung)
# (dysp _|_ xray, lung | asia, either, smoke, bronc, tub)
# (dysp _|_ tub | asia, either, smoke, xray, lung)
# (dysp _|_ lung | asia, either, smoke, xray, tub)
# (dysp _|_ xray | asia, either, smoke, lung, tub)
# (dysp _|_ smoke, tub | asia, either, bronc, xray, lung)
# (dysp _|_ smoke, lung | asia, either, bronc, xray, tub)
# (dysp _|_ smoke, xray | asia, either, bronc, lung, tub)
# (dysp _|_ smoke | asia, bronc, xray, lung, tub)
# (dysp _|_ asia, tub | either, smoke, bronc, xray, lung)
# (dysp _|_ asia, lung | either, smoke, bronc, xray, tub)
# (dysp _|_ asia, xray | either, smoke, bronc, lung, tub)
# (dysp _|_ asia | either, smoke, xray, lung, tub)
# (dysp _|_ asia, smoke | either, bronc, xray, lung, tub)
# (dysp _|_ asia | smoke, bronc, xray, lung, tub)
# (dysp _|_ tub | asia, either, smoke, bronc, xray, lung)
# (dysp _|_ lung | asia, either, smoke, bronc, xray, tub)
# (dysp _|_ xray | asia, either, smoke, bronc, lung, tub)
# (dysp _|_ smoke | asia, either, bronc, xray, lung, tub)
# (dysp _|_ asia | either, smoke, bronc, xray, lung, tub)

# %% [markdown]
# ## Make Inferences

# %% [markdown]
# **Q1.** What is the probability of a person having bronchitis given that he/she doesn't smoke?

# %%
# initialise inference class
infer = VariableElimination(asia_model)

# make query
bronchitis = infer.query(variables=['bronc'], evidence={'smoke': 0})

# print result
print(bronchitis['bronc'])
# Out:
# ╒═════════╤══════════════╕
# │ bronc   │   phi(bronc) │
# ╞═════════╪══════════════╡
# │ bronc_0 │       0.6000 │
# ├─────────┼──────────────┤
# │ bronc_1 │       0.4000 │
# ╘═════════╧══════════════╛

# %% [markdown]
# What is the probability that the person is a smoker given that their x-ray result is positive?

# %% [markdown]
# **Q2.** What is the probability that the person is a smoker given that their x-ray result is positive

# %%
smoker = infer.query(variables=['smoke'], evidence={'xray': 1})
print(smoker['smoke'])
# Out:
# ╒═════════╤══════════════╕
# │ smoke   │   phi(smoke) │
# ╞═════════╪══════════════╡
# │ smoke_0 │       0.4767 │
# ├─────────┼──────────────┤
# │ smoke_1 │       0.5233 │
# ╘═════════╧══════════════╛

# %% [markdown]
# **Q3.** Consider the following two probabilities:
#
# 1. The probability that a person doesn't have dyspnea given that he has bronchitis.
# 2. The probability that a person doesn't have dyspnea given that he has bronchitis and doesn't have lung cancer.
#
# By what percent does the probability increase or decrease from situation 1 to situation 2?

# %%
dyspnea_b = infer.query(variables=['dysp'], evidence={'bronc': 1})
print(dyspnea_b['dysp'])

dyspnea_b_l = infer.query(variables=['dysp'], evidence={'bronc': 1, 'lung': 0})
print(dyspnea_b_l['dysp'])
# Out:
# ╒════════╤═════════════╕
# │ dysp   │   phi(dysp) │
# ╞════════╪═════════════╡
# │ dysp_0 │      0.1369 │
# ├────────┼─────────────┤
# │ dysp_1 │      0.8631 │
# ╘════════╧═════════════╛
# ╒════════╤═════════════╕
# │ dysp   │   phi(dysp) │
# ╞════════╪═════════════╡
# │ dysp_0 │      0.8000 │
# ├────────┼─────────────┤
# │ dysp_1 │      0.2000 │
# ╘════════╧═════════════╛

# %% [markdown]
# Probability of not having Dyspnea changed from 14% to 80%. The percentage change is ((0.80-0.14)*100)/(0.14) = +471.43%
